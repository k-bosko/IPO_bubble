# %% [markdown]
# ### IPO price scraper - see IPO_price_scraper_v2.ipynb for updated version

# %% [markdown]
# In this script, I will scrape the stock info and company profile from Yahoo Finance for the IPO companies scraped in the previous step from NASDAQ site (see IPO_scraper.ipynb)

# %%
from difflib import SequenceMatcher
import pandas_datareader.data as pdr #Yahoo Finance ticker
import pandas as pd
import numpy as np

from datetime import datetime

from bs4 import BeautifulSoup
import requests
from time import sleep

# %%
df = pd.read_csv('ipo_clean_2010_2018.csv', parse_dates=['Date Priced', 'year'])
df.shape
# Out:
# (1600, 13)

# %%
df.dtypes
# Out:
# Company Name            object
# Symbol                  object
# Market                  object
# Price                  float64
# Shares                 float64
# Offer Amount           float64
# Date Priced     datetime64[ns]
# employees              float64
# address                 object
# US_state                object
# descriptions            object
# link_nasdaq             object
# year            datetime64[ns]
# dtype: object

# %% [markdown]
# ## Checking for duplicated tickers and company names:

# %%
print("number of duplicated companies in the dataset:", df['Company Name'].duplicated().sum())
# Out:
# number of duplicated companies in the dataset: 3

# %%
df[df['Company Name'].duplicated(keep=False)]
# Out:
#                       Company Name Symbol                   Market  Price  \
# 85    AMBOW EDUCATION HOLDING LTD.   AMBO  New York Stock Exchange  10.00
# 205           SANDRIDGE ENERGY INC    SDT  New York Stock Exchange  21.00
# 254           SANDRIDGE ENERGY INC    PER  New York Stock Exchange  18.00
# 341           SANDRIDGE ENERGY INC    SDR  New York Stock Exchange  21.00
# 1503  AMBOW EDUCATION HOLDING LTD.   AMBO                 NYSE MKT   4.25
#
#         Shares  Offer Amount Date Priced  employees  \
# 85    10677207     106772070  2010-08-05    10361.0
# 205   15000000     315000000  2011-04-07     2192.0
# 254   30000000     540000000  2011-08-11     2192.0
# 341   26000000     546000000  2012-04-18        NaN
# 1503   1800000       7650000  2018-06-01     2657.0
#
#                                                 address US_state  \
# 85    12TH FLOOR, NO. 1 FINANCIAL STREETCHANG AN CEN...      NaN
# 205   123 ROBERT S. KERR AVENUEOKLAHOMA CITY, OK 731...       OK
# 254   123 ROBERT S. KERR AVENUEOKLAHOMA CITY, OK 731...       OK
# 341   123 ROBERT S. KERR AVENUEOKLAHOMA CITY, OK 731...       OK
# 1503  12TH FLOOR, NO. 1 FINANCIAL STREETCHANG AN CEN...      NaN
#
#                                            descriptions  \
# 85    We are a leading national provider of educatio...
# 205   SandRidge Mississippian Trust I is a Delaware ...
# 254   SandRidge Permian Trust is a Delaware statutor...
# 341   SandRidge Mississippian Trust II is a Delaware...
# 1503  Our mission is to provide Better Schools, Bett...
#
#                                             link_nasdaq  year
# 85    https://www.nasdaq.com/markets/ipos/company/am...  2010
# 205   https://www.nasdaq.com/markets/ipos/company/sa...  2011
# 254   https://www.nasdaq.com/markets/ipos/company/sa...  2011
# 341   https://www.nasdaq.com/markets/ipos/company/sa...  2012
# 1503  https://www.nasdaq.com/markets/ipos/company/am...  2018

# %% [markdown]
# Commentary: Ambow Education LTD was enlisted twice. The first one it was liquedated after a scandal in 2014 [1]
# Sandridge Energy Inc - all three are different trusts that belong to one company. Technically they are different.
#
# 1. https://ir.theice.com/press/press-releases/nyse-regulation/2014/nyse-to-immediately-suspend-trading-in-american-depository

# %%
print("number of duplicated tickers in the dataset:", df['Symbol'].duplicated().sum())
# Out:
# number of duplicated tickers in the dataset: 7

# %%
df.iloc[:, :7][df['Symbol'].duplicated(keep=False)]
# Out:
#                                     Company Name Symbol  \
# 60                     HIGHER ONE HOLDINGS, INC.    ONE
# 85                  AMBOW EDUCATION HOLDING LTD.   AMBO
# 97                SEACUBE CONTAINER LEASING LTD.    BOX
# 293                              BAZAARVOICE INC     BV
# 331                            ACQUITY GROUP LTD     AQ
# 356                      TIAA FSB HOLDINGS, INC.   EVER
# 715                     QUOTIENT TECHNOLOGY INC.   COUP
# 948                                      BOX INC    BOX
# 1207                          COUPA SOFTWARE INC   COUP
# 1374                               AQUANTIA CORP     AQ
# 1428  ONESMART INTERNATIONAL EDUCATION GROUP LTD    ONE
# 1477                   BRIGHTVIEW HOLDINGS, INC.     BV
# 1479                             EVERQUOTE, INC.   EVER
# 1503                AMBOW EDUCATION HOLDING LTD.   AMBO
#
#                        Market  Price    Shares  Offer Amount Date Priced
# 60    New York Stock Exchange  12.00   9000000     108000000  2010-06-17
# 85    New York Stock Exchange  10.00  10677207     106772070  2010-08-05
# 97    New York Stock Exchange  10.00   9500000      95000000  2010-10-28
# 293                    NASDAQ  12.00   9484296     113811552  2012-02-24
# 331   American Stock Exchange   6.00   5555556      33333336  2012-04-27
# 356   New York Stock Exchange  10.00  19220000     192200000  2012-05-03
# 715   New York Stock Exchange  16.00  10500000     168000000  2014-03-07
# 948   New York Stock Exchange  14.00  12500000     175000000  2015-01-23
# 1207     NASDAQ Global Select  18.00   7400000     133200000  2016-10-06
# 1374                     NYSE   9.00   6818000      61362000  2017-11-03
# 1428                     NYSE  11.00  16300000     179300000  2018-03-28
# 1477                     NYSE  22.00  21300000     468600000  2018-06-28
# 1479            NASDAQ Global  18.00   4687500      84375000  2018-06-28
# 1503                 NYSE MKT   4.25   1800000       7650000  2018-06-01

# %% [markdown]
# Commentary: There are companies that either got defunct and their tickers were given to new IPOs (like EVER) or there are companies that went to IPO twice (like AMBOW). Either way, because I will scrape stock data based on tickers from Yahoo Finance, which has information only for the most recent company, I keep here only those companies that went to IPO later. Others, I declare defunct.

# %%
defunct_oldticker = df['Symbol'][df['Symbol'].duplicated(keep='last')]

# %%
df = df[~df['Symbol'].duplicated(keep='last')]

# %%
df.shape
# Out:
# (1593, 13)

# %% [markdown]
# ## Checking suspicious misalignment between company name and its ticker:

# %% [markdown]
# After scraping IPO companies I noticed that there are some misalignments between company names and their tickers. This could be due to the fact that some companies are now defunct and their tickers belong now to other companies. Or maybe the company is still functional but changed its ticker. Or maybe there was mistake when entering the ticker on Nasdaq website.
#
# So in this step, I check if letters in the symbol correspond to company name. If they don't, I construct a dict of suspect companies. In the next step, I check these suspicious tickers on Yahoo Finance, retrieve their company names their and compare to company names on Nasdaq list.

# %%
companies_tocheck = {}
for i, symbol in enumerate(df.Symbol):
    for letter in symbol:
        #print(letter)
        if letter not in df.iloc[i, 0]:
            companies_tocheck.update({df.iloc[i, 0]: symbol})

# %%
print(f"{len(companies_tocheck)} companies have suspicious tickers. Will be checked")
# Out:
# 284 companies have suspicious tickers. Will be checked

# %%
url_1 = 'https://finance.yahoo.com/quote/%s/'
url_2 = 'profile?p=%s'
unmatched = {}
unmatched_tickers = []

for i, ticker in enumerate(list(companies_tocheck.values())):
    print(f"scraping {ticker} - {i+1}/{len(companies_tocheck)}")
    result = requests.get(url_1 % ticker + url_2 % ticker)
    content = result.content

    soup = BeautifulSoup(content)
    data = soup.find_all("h1", {"class":"D(ib) Fz(16px) Lh(18px)"})
    if data:
        txt = str([x.get_text() for x in data]).replace(ticker, "").lower()
        regex = re.compile("\w+")
        txt = " ".join(regex.findall(txt)).replace("corporation", "corp").replace("limited", "ltd")
        name = df['Company Name'][df['Symbol'] == ticker].values[0].lower().replace(",", "").replace(".", "").replace("corporation", "corp").replace("limited", "ltd")
        #checking with SequenceMatcher if two strings match for at least 80%
        if SequenceMatcher(None, txt, name).ratio() < 0.8:
            unmatched.update({name: txt})
            unmatched_tickers.append(ticker)
# Out:
# scraping CTC - 1/284
# scraping STNG - 2/284
# scraping FIBK - 3/284
# scraping DHRM - 4/284
# scraping AH - 5/284
# scraping PLOW - 6/284
# scraping SANWU - 7/284
# scraping HSFT - 8/284
# scraping VRNGU - 9/284
# scraping CHKM - 10/284
# scraping OINK - 11/284
# scraping OXF - 12/284
# scraping ECT - 13/284
# scraping AMAP - 14/284
# scraping GMAN - 15/284
# scraping DMED - 16/284
# scraping TSRX - 17/284
# scraping SFUN - 18/284
# scraping XRS - 19/284
# scraping CCG - 20/284
# scraping XNY - 21/284
# scraping KFFG - 22/284
# scraping VTUS - 23/284
# scraping LAS - 24/284
# scraping FXCM - 25/284
# scraping DMD - 26/284
# scraping IFT - 27/284
# scraping MEDH - 28/284
# scraping PCRX - 29/284
# scraping TRNX - 30/284
# scraping QIHU - 31/284
# scraping MX - 32/284
# scraping MKTG - 33/284
# scraping TEU - 34/284
# scraping GMLP - 35/284
# scraping UAN - 36/284
# scraping PER - 37/284
# scraping TZYM - 38/284
# scraping SZYM - 39/284
# scraping SAVE - 40/284
# scraping FENG - 41/284
# scraping NQ - 42/284
# scraping WIFI - 43/284
# scraping FBNK - 44/284
# scraping GSJK - 45/284
# scraping CJES - 46/284
# scraping SXC - 47/284
# scraping ARCP - 48/284
# scraping BLMT - 49/284
# scraping DLPH - 50/284
# scraping RNF - 51/284
# scraping NRGM - 52/284
# scraping KORS - 53/284
# scraping CZR - 54/284
# scraping BNNY - 55/284
# scraping WHZ - 56/284
# scraping VNTV - 57/284
# scraping EAC - 58/284
# scraping EVAC - 59/284
# scraping PDH - 60/284
# scraping ROYT - 61/284
# scraping HPTX - 62/284
# scraping DRTX - 63/284
# scraping FSBW - 64/284
# scraping MEILU - 65/284
# scraping LGP - 66/284
# scraping FANG - 67/284
# scraping LNCO - 68/284
# scraping FLTX - 69/284
# scraping ALDW - 70/284
# scraping SXE - 71/284
# scraping WGP - 72/284
# scraping KBIO - 73/284
# scraping TPH - 74/284
# scraping LPDX - 75/284
# scraping SXCP - 76/284
# scraping HIIQ - 77/284
# scraping ZFC - 78/284
# scraping NVEEU - 79/284
# scraping OAKS - 80/284
# scraping FWM - 81/284
# scraping IBTX - 82/284
# scraping ECOM - 83/284
# scraping DATA - 84/284
# scraping UBIC - 85/284
# scraping BIOAU - 86/284
# scraping PFSI - 87/284
# scraping PETX - 88/284
# scraping TRMR - 89/284
# scraping FISH - 90/284
# scraping ONTX - 91/284
# scraping HTBX - 92/284
# scraping PSXP - 93/284
# scraping SALE - 94/284
# scraping XGTI - 95/284
# scraping DOC - 96/284
# scraping NYLD - 97/284
# scraping RGDO - 98/284
# scraping QEPM - 99/284
# scraping OPHT - 100/284
# scraping MYCC - 101/284
# scraping XLRN - 102/284
# scraping FPRX - 103/284
# scraping WUBA - 104/284
# scraping LEAF - 105/284
# scraping MGNX - 106/284
# scraping WBAI - 107/284
# scraping ARCX - 108/284
# scraping CQH - 109/284
# scraping SALT - 110/284
# scraping CLDN - 111/284
# scraping RICE - 112/284
# scraping HELI - 113/284
# scraping RTRX - 114/284
# scraping AMDA - 115/284
# scraping EGRX - 116/284
# scraping CBPX - 117/284
# scraping CBSO - 118/284
# scraping TWOU - 119/284
# scraping WATT - 120/284
# scraping SQBK - 121/284
# scraping RTGN - 122/284
# scraping VSAR - 123/284
# scraping QTWO - 124/284
# scraping RXDX - 125/284
# scraping DPRX - 126/284
# scraping AKAO - 127/284
# scraping EVAR - 128/284
# scraping VGGL - 129/284
# scraping VTL - 130/284
# scraping CERU - 131/284
# scraping SYRX - 132/284
# scraping TEDU - 133/284
# scraping AGRX - 134/284
# scraping PBFX - 135/284
# scraping KTWO - 136/284
# scraping FRSH - 137/284
# scraping ALDX - 138/284
# scraping MIK - 139/284
# scraping VNOM - 140/284
# scraping SGNL - 141/284
# scraping ABY - 142/284
# scraping MRD - 143/284
# scraping MCUR - 144/284
# scraping ORPN - 145/284
# scraping RIGP - 146/284
# scraping CFRXU - 147/284
# scraping WMS - 148/284
# scraping XENT - 149/284
# scraping IMDZ - 150/284
# scraping ROKA - 151/284
# scraping BNK - 152/284
# scraping HMLP - 153/284
# scraping TKAI - 154/284
# scraping SHLX - 155/284
# scraping PLAY - 156/284
# scraping VBTX - 157/284
# scraping NEOT - 158/284
# scraping EYES - 159/284
# scraping PGRE - 160/284
# scraping JYNT - 161/284
# scraping INCR - 162/284
# scraping TBK - 163/284
# scraping MDVXU - 164/284
# scraping CNXR - 165/284
# scraping HDP - 166/284
# scraping HSGX - 167/284
# scraping HIFR - 168/284
# scraping ONCE - 169/284
# scraping LENS - 170/284
# scraping FLKS - 171/284
# scraping ICBK - 172/284
# scraping CHEKU - 173/284
# scraping DEA - 174/284
# scraping FSB - 175/284
# scraping VKTX - 176/284
# scraping CDTX - 177/284
# scraping CBYL - 178/284
# scraping WOWO - 179/284
# scraping BKFS - 180/284
# scraping RKDA - 181/284
# scraping JAGX - 182/284
# scraping LIFE - 183/284
# scraping MCRB - 184/284
# scraping GNRT - 185/284
# scraping CAFD - 186/284
# scraping NVLS - 187/284
# scraping DNAI - 188/284
# scraping CNXC - 189/284
# scraping BETR - 190/284
# scraping MPSX - 191/284
# scraping DMTX - 192/284
# scraping RACE - 193/284
# scraping CERCU - 194/284
# scraping PMTS - 195/284
# scraping ABTX - 196/284
# scraping MIRN - 197/284
# scraping EQBK - 198/284
# scraping FORK - 199/284
# scraping TEAM - 200/284
# scraping PAVMU - 201/284
# scraping SCWX - 202/284
# scraping PZRX - 203/284
# scraping PBNC - 204/284
# scraping MBRX - 205/284
# scraping APOP - 206/284
# scraping LTEA - 207/284
# scraping TCMD - 208/284
# scraping BOLD - 209/284
# scraping MSDI - 210/284
# scraping PTGX - 211/284
# scraping FHB - 212/284
# scraping TYHT - 213/284
# scraping FBK - 214/284
# scraping NBLX - 215/284
# scraping GOLF - 216/284
# scraping RARX - 217/284
# scraping TUSK - 218/284
# scraping MRAM - 219/284
# scraping ADSW - 220/284
# scraping AMMA - 221/284
# scraping WAAS - 222/284
# scraping WRD - 223/284
# scraping FRAC - 224/284
# scraping METC - 225/284
# scraping VLRX - 226/284
# scraping PUMP - 227/284
# scraping XRF - 228/284
# scraping WTTR - 229/284
# scraping HCC - 230/284
# scraping GTHX - 231/284
# scraping NDRAU - 232/284
# scraping AMGP - 233/284
# scraping ATXI - 234/284
# scraping SGBX - 235/284
# scraping CODX - 236/284
# scraping PETZ - 237/284
# scraping IPOAU - 238/284
# scraping MBIN - 239/284
# scraping EYE - 240/284
# scraping KIDS - 241/284
# scraping HAIR - 242/284
# scraping BXG - 243/284
# scraping LEVB - 244/284
# scraping PPDF - 245/284
# scraping DOGZ - 246/284
# scraping GIG'U - 247/284
# scraping CDLX - 248/284
# scraping WHD - 249/284
# scraping UMRX - 250/284
# scraping OPBK - 251/284
# scraping FIXX - 252/284
# scraping DNJR - 253/284
# scraping LASR - 254/284
# scraping CDAY - 255/284
# scraping OBNK - 256/284
# scraping ROAD - 257/284
# scraping BCML - 258/284
# scraping UBX - 259/284
# scraping XSPL - 260/284
# scraping ENTX - 261/284
# scraping STIM - 262/284
# scraping NTGN - 263/284
# scraping EIDX - 264/284
# scraping NEW - 265/284
# scraping WISA - 266/284
# scraping JG - 267/284
# scraping MYFW - 268/284
# scraping CRNX - 269/284
# scraping CCB - 270/284
# scraping RUBY - 271/284
# scraping BNGOU - 272/284
# scraping PCB - 273/284
# scraping ARCE - 274/284
# scraping CBNK - 275/284
# scraping ETTX - 276/284
# scraping BSVN - 277/284
# scraping XYF - 278/284
# scraping YI - 279/284
# scraping ORTX - 280/284
# scraping MSC - 281/284
# scraping LTHM - 282/284
# scraping PHCF - 283/284
# scraping QFIN - 284/284

# %%
print(f'there are {len(unmatched_tickers)} unmatched tickers. Will be removed')
unmatched
# Out:
# there are 24 unmatched tickers. Will be removed
# {'energy corp of america': 'eca marcellus trust i',
#  'g-estate liquidation stores inc': 'goldman sachs motif manufacturing revolution etf',
#  'assembly biosciences inc': 'virgin trains usa llc',
#  'mmodal inc': 'medx holdings inc',
#  'wright medical group nv': 'taronis technologies inc',
#  'sandridge energy inc': 'sandridge permian trust',
#  'vereit inc': 'american realty capital propert',
#  'aptiv plc': 'delphi technologies plc',
#  'worldpay inc': 'vantiv inc class a',
#  'hunt companies finance trust inc': 'five oaks investment corp',
#  'pnmac holdings inc': 'pennymac financial services inc',
#  'retailmenot inc': 'retailmenot inc series 1',
#  'onemain holdings inc': 'leaf group ltd',
#  'zenith energy logistics partners lp': 'arc logistic partners lp common',
#  'eqt re llc': 'rice energy inc',
#  'aravive inc': 'versartis inc',
#  'plx pharma inc': 'dipexium pharmaceuticals inc',
#  'immunic inc': 'vital therapies inc',
#  'miragen therapeutics inc': 'signal genetics inc',
#  'leap therapeutics inc': 'macrocure ltd ordinary share',
#  'enlivex therapeutics ltd': 'bioblast pharma ltd',
#  'kalvista pharmaceuticals inc': 'carbylan therapeutics inc',
#  'sierra oncology inc': 'pronai therapeutics inc',
#  'cbdmd inc': 'level brands inc'}

# %%
df = df[~df['Symbol'].isin(unmatched_tickers)]

# %%
df.shape
# Out:
# (1569, 13)

# %% [markdown]
# ### 1.1. Scraping stock data

# %%
df_yahoo = pd.DataFrame()
notscraped = []
for i, ticker in enumerate(df.Symbol):
    try:
        print(f"scraping {ticker} - {i+1}/{len(df.Symbol)}")
        st = pdr.DataReader(ticker, "yahoo")
        firstday_open = st['Open'][0]
        firstday_spread = st['High'][0] - st['Low'][0] #diff between high and low price on the first day of trading
        firstday_volume = st['Volume'][0]
        firstday_adjclose = st['Adj Close'][0]
        inweek_open = st['Open'][7]
        inweek_spread = st['High'][7] - st['Low'][7]
        inweek_volume = st['Volume'][7]
        inweek_adjclose = st['Adj Close'][7]
        inmonth_open = st['Open'][30]
        inmonth_spread = st['High'][30] - st['Low'][30]
        inmonth_volume = st['Volume'][30]
        inmonth_adjclose = st['Adj Close'][30]
        ticker_df = pd.DataFrame({ticker: {'firstday_open': firstday_open, 'firstday_spread': firstday_spread, 
                                  'firstday_volume': firstday_volume, 'firstday_adjclose': firstday_adjclose,
                                  'inweek_open': inweek_open, 'inweek_spread': inweek_spread, 
                                  'inweek_volume': inweek_volume, 'inweek_adjclose': inweek_adjclose, 
                                  'inmonth_open': inmonth_open, 'inmonth_spread': inmonth_spread, 
                                  'inmonth_volume': inmonth_volume, 'inmonth_adjclose': inmonth_adjclose}}).T
        df_yahoo = df_yahoo.append(ticker_df)
    except:
        notscraped.append(ticker)
        continue
# Out:
# scraping CTC - 1/1569
# scraping AMCF - 2/1569
# scraping CHC - 3/1569
# scraping CHSP - 4/1569
# scraping CLU - 5/1569
# scraping SYA - 6/1569
# scraping GNRC - 7/1569
# scraping GRM - 8/1569
# scraping QNST - 9/1569
# scraping TRNO - 10/1569
# scraping PDM - 11/1569
# scraping IRWD - 12/1569
# scraping MERU - 13/1569
# scraping SSNC - 14/1569
# scraping STNG - 15/1569
# scraping HTHT - 16/1569
# scraping CRMD - 17/1569
# scraping FIBK - 18/1569
# scraping CALX - 19/1569
# scraping MXL - 20/1569
# scraping FNGN - 21/1569
# scraping CRU - 22/1569
# scraping AVEO - 23/1569
# scraping ST - 24/1569
# scraping BALT - 25/1569
# scraping ANTH - 26/1569
# scraping PNG - 27/1569
# scraping CNVO - 28/1569
# scraping AOSL - 29/1569
# scraping EXL - 30/1569
# scraping GGS - 31/1569
# scraping MITL - 32/1569
# scraping CDXS - 33/1569
# scraping ALIM - 34/1569
# scraping DHRM - 35/1569
# scraping DVOX - 36/1569
# scraping SPSC - 37/1569
# scraping RLOC - 38/1569
# scraping AH - 39/1569
# scraping CLDT - 40/1569
# scraping MUSA - 41/1569
# scraping TNGN - 42/1569
# scraping PRI - 43/1569
# scraping GNMK - 44/1569
# scraping NOR - 45/1569
# scraping JKS - 46/1569
# scraping KONE - 47/1569
# scraping EXPR - 48/1569
# scraping RRTS - 49/1569
# scraping TNAV - 50/1569
# scraping NKA - 51/1569
# scraping CHRM - 52/1569
# scraping PLOW - 53/1569
# scraping SANWU - 54/1569
# scraping HSFT - 55/1569
# scraping TSLA - 56/1569
# scraping FN - 57/1569
# scraping VRNGU - 58/1569
# scraping MOTR - 59/1569
# scraping OAS - 60/1569
# scraping BSFT - 61/1569
# scraping BORN - 62/1569
# scraping CHKM - 63/1569
# scraping MCP - 64/1569
# scraping GDOT - 65/1569
# scraping AMRC - 66/1569
# scraping CIS - 67/1569
# scraping OINK - 68/1569
# scraping QLIK - 69/1569
# scraping RLD - 70/1569
# scraping SMT - 71/1569
# scraping OXF - 72/1569
# scraping AMAP - 73/1569
# scraping WSR - 74/1569
# scraping ELMD - 75/1569
# scraping MMYT - 76/1569
# scraping RP - 77/1569
# scraping KH - 78/1569
# scraping MDMD - 79/1569
# scraping IL - 80/1569
# scraping NXPI - 81/1569
# scraping PATH - 82/1569
# scraping DMED - 83/1569
# scraping TSRX - 84/1569
# scraping ELT - 85/1569
# scraping RNO - 86/1569
# scraping AMRS - 87/1569
# scraping CCSC - 88/1569
# scraping SQI - 89/1569
# scraping COR - 90/1569
# scraping SFUN - 91/1569
# scraping GAGA - 92/1569
# scraping EXAM - 93/1569
# scraping PACB - 94/1569
# scraping MCOX - 95/1569
# scraping AEGR - 96/1569
# scraping BBRG - 97/1569
# scraping VRA - 98/1569
# scraping XRS - 99/1569
# scraping SHP - 100/1569
# scraping NTSP - 101/1569
# scraping BODY - 102/1569
# scraping TOWR - 103/1569
# scraping CCG - 104/1569
# scraping GEDU - 105/1569
# scraping EFC - 106/1569
# scraping DQ - 107/1569
# scraping STND - 108/1569
# scraping CCIH - 109/1569
# scraping KEYW - 110/1569
# scraping GLBS - 111/1569
# scraping ANAC - 112/1569
# scraping SYSW - 113/1569
# scraping XNY - 114/1569
# scraping ZGNX - 115/1569
# scraping ARX - 116/1569
# scraping LZEN - 117/1569
# scraping KFFG - 118/1569
# scraping GM - 119/1569
# scraping LPLA - 120/1569
# scraping BAH - 121/1569
# scraping BITA - 122/1569
# scraping IPHI - 123/1569
# scraping GNOM - 124/1569
# scraping HHC - 125/1569
# scraping NOAH - 126/1569
# scraping PRMW - 127/1569
# scraping TFM - 128/1569
# scraping CMRE - 129/1569
# scraping CTE - 130/1569
# scraping SODA - 131/1569
# scraping XUE - 132/1569
# scraping OCIR - 556/1569
# scraping ESNT - 557/1569
# scraping MMI - 558/1569
# scraping WUBA - 559/1569
# scraping VCYT - 560/1569
# scraping SCAI - 561/1569
# scraping BRX - 562/1569
# scraping CRTO - 563/1569
# scraping COMM - 564/1569
# scraping SRLP - 565/1569
# scraping EIGI - 566/1569
# scraping AERI - 567/1569
# scraping VJET - 568/1569
# scraping ABGB - 569/1569
# scraping VEEV - 570/1569
# scraping PAGP - 571/1569
# scraping SGM - 572/1569
# scraping WNRL - 573/1569
# scraping MGNX - 574/1569
# scraping AR - 575/1569
# scraping LDRH - 576/1569
# scraping SFXE - 577/1569
# scraping QTS - 578/1569
# scraping PBPB - 579/1569
# scraping OCIP - 580/1569
# scraping CHMI - 581/1569
# scraping BURL - 582/1569
# scraping ESRT - 583/1569
# scraping RMAX - 584/1569
# scraping FATE - 585/1569
# scraping GOMO - 586/1569
# scraping IPWR - 587/1569
# scraping OXFD - 588/1569
# scraping VNCE - 589/1569
# scraping WBAI - 590/1569
# scraping NVGS - 591/1569
# scraping EVGN - 592/1569
# scraping ZU - 593/1569
# scraping RLYP - 594/1569
# scraping TNDM - 595/1569
# scraping HMHC - 596/1569
# scraping EROS - 597/1569
# scraping DLNG - 598/1569
# scraping CHGG - 599/1569
# scraping STAY - 600/1569
# scraping NMIH - 601/1569
# scraping JGW - 602/1569
# scraping LGIH - 603/1569
# scraping MEP - 604/1569
# scraping MVNR - 605/1569
# scraping NCFT - 606/1569
# scraping TWTR - 607/1569
# scraping WIX - 608/1569
# scraping KPTI - 609/1569
# scraping CUDA - 610/1569
# scraping AVH - 611/1569
# scraping BCRH - 612/1569
# scraping TCS - 613/1569
# scraping QUNR - 614/1569
# scraping AMC - 615/1569
# scraping CQH - 616/1569
# scraping NMBL - 617/1569
# scraping FGL - 618/1569
# scraping HLT - 619/1569
# scraping KIN - 620/1569
# scraping SALT - 621/1569
# scraping TLOG - 622/1569
# scraping CTT - 623/1569
# scraping ARMK - 624/1569
# scraping ATHM - 625/1569
# scraping VLP - 626/1569
# scraping KFX - 627/1569
# scraping XNCR - 628/1569
# scraping CARA - 629/1569
# scraping NWHM - 630/1569
# scraping RARE - 631/1569
# scraping MBUU - 632/1569
# scraping SNOW - 633/1569
# scraping TRVN - 634/1569
# scraping CLDN - 635/1569
# scraping DRNA - 636/1569
# scraping NADL - 637/1569
# scraping CRCM - 638/1569
# scraping AKER - 639/1569
# scraping SC - 640/1569
# scraping RSPP - 641/1569
# scraping EPE - 642/1569
# scraping HELI - 643/1569
# scraping CELP - 644/1569
# scraping GLYC - 645/1569
# scraping RTRX - 646/1569
# scraping VRNS - 647/1569
# scraping LMNS - 648/1569
# scraping SMLR - 649/1569
# scraping INGN - 650/1569
# scraping IBP - 651/1569
# scraping AMDA - 652/1569
# scraping CNCE - 653/1569
# scraping EGRX - 654/1569
# scraping FLXN - 655/1569
# scraping TLMR - 656/1569
# scraping NRX - 657/1569
# scraping GPRK - 658/1569
# scraping ARGS - 659/1569
# scraping EBIO - 660/1569
# scraping HTGM - 976/1569
# scraping ADAP - 977/1569
# scraping CLCD - 978/1569
# scraping OPGN - 979/1569
# scraping BSM - 980/1569
# scraping ALRM - 981/1569
# scraping APPF - 982/1569
# scraping GPP - 983/1569
# scraping MCRB - 984/1569
# scraping XTLY - 985/1569
# scraping YECO - 986/1569
# scraping TRU - 987/1569
# scraping MCRN - 988/1569
# scraping LNTH - 989/1569
# scraping GKOS - 990/1569
# scraping GNRT - 991/1569
# scraping CATB - 992/1569
# scraping RTTR - 993/1569
# scraping MB - 994/1569
# scraping CYAD - 995/1569
# scraping CAFD - 996/1569
# scraping FOGO - 997/1569
# scraping FIT - 998/1569
# scraping UNVR - 999/1569
# scraping NVLS - 1000/1569
# scraping IVTY - 1001/1569
# scraping WING - 1002/1569
# scraping PUB - 1003/1569
# scraping AXON - 1004/1569
# scraping BITI - 1005/1569
# scraping EVH - 1006/1569
# scraping DTEA - 1007/1569
# scraping GI - 1008/1569
# scraping PTXP - 1009/1569
# scraping AQMS - 1010/1569
# scraping GLBL - 1011/1569
# scraping XELB - 1012/1569
# scraping VTVT - 1013/1569
# scraping NK - 1014/1569
# scraping NEOS - 1015/1569
# scraping LOB - 1016/1569
# scraping BUFF - 1017/1569
# scraping MCFT - 1018/1569
# scraping OOMA - 1019/1569
# scraping RPD - 1020/1569
# scraping OLLI - 1021/1569
# scraping JP - 1022/1569
# scraping CHMA - 1023/1569
# scraping HLG - 1024/1569
# scraping NTRA - 1025/1569
# scraping CNXC - 1026/1569
# scraping CFMS - 1027/1569
# scraping TDOC - 1028/1569
# scraping UFAB - 1029/1569
# scraping BNTC - 1030/1569
# scraping HLI - 1031/1569
# scraping GBT - 1032/1569
# scraping AIMT - 1033/1569
# scraping PLNT - 1034/1569
# scraping RUN - 1035/1569
# scraping ZYNE - 1036/1569
# scraping BETR - 1037/1569
# scraping NTEC - 1038/1569
# scraping NBRV - 1039/1569
# scraping PEN - 1040/1569
# scraping RGNX - 1041/1569
# scraping MYOK - 1042/1569
# scraping IOTS - 1043/1569
# scraping LMFAU - 1044/1569
# scraping OASM - 1045/1569
# scraping MPSX - 1046/1569
# scraping DMTX - 1047/1569
# scraping RACE - 1048/1569
# scraping AFCO - 1049/1569
# scraping SBBP - 1050/1569
# scraping CERCU - 1051/1569
# scraping FDC - 1052/1569
# scraping PMTS - 1053/1569
# scraping CTMX - 1054/1569
# scraping ABTX - 1055/1569
# scraping ACRS - 1056/1569
# scraping PSTG - 1057/1569
# scraping NVCR - 1058/1569
# scraping PFGC - 1059/1569
# scraping MIRN - 1060/1569
# scraping EDGE - 1061/1569
# scraping SGRY - 1062/1569
# scraping DLTH - 1063/1569
# scraping KTOV - 1064/1569
# scraping AXSM - 1065/1569
# scraping MIME - 1066/1569
# scraping MTCH - 1067/1569
# scraping SQ - 1068/1569
# scraping MESO - 1069/1569
# scraping INST - 1070/1569
# scraping XCOM - 1071/1569
# scraping VYGR - 1072/1569
# scraping WVE - 1073/1569
# scraping AAAP - 1074/1569
# scraping EQBK - 1075/1569
# scraping CWH - 1174/1569
# scraping MRAM - 1175/1569
# scraping ADSW - 1176/1569
# scraping OBLN - 1177/1569
# scraping COUP - 1178/1569
# scraping AMMA - 1179/1569
# scraping WAAS - 1180/1569
# scraping MTFB - 1181/1569
# scraping SND - 1182/1569
# scraping GDS - 1183/1569
# scraping HEBT - 1184/1569
# scraping TRVG - 1185/1569
# scraping TIG - 1186/1569
# scraping WRD - 1187/1569
# scraping ICHR - 1188/1569
# scraping SNES - 1189/1569
# scraping POLA - 1190/1569
# scraping IIPR - 1191/1569
# scraping JAG - 1192/1569
# scraping JELD - 1193/1569
# scraping JNCE - 1194/1569
# scraping REVG - 1195/1569
# scraping OBSV - 1196/1569
# scraping ANAB - 1197/1569
# scraping FRAC - 1198/1569
# scraping CLPR - 1199/1569
# scraping FBM - 1200/1569
# scraping SACH - 1201/1569
# scraping METC - 1202/1569
# scraping KRP - 1203/1569
# scraping LAUR - 1204/1569
# scraping INVH - 1205/1569
# scraping AYX - 1206/1569
# scraping VLRX - 1207/1569
# scraping TRPX - 1208/1569
# scraping PUMP - 1209/1569
# scraping MULE - 1210/1569
# scraping ARD - 1211/1569
# scraping PSDO - 1212/1569
# scraping JILL - 1213/1569
# scraping BYSI - 1214/1569
# scraping SNAP - 1215/1569
# scraping HLNE - 1216/1569
# scraping CLDR - 1217/1569
# scraping CVNA - 1218/1569
# scraping EEX - 1219/1569
# scraping NCSM - 1220/1569
# scraping XRF - 1221/1569
# scraping ZYME - 1222/1569
# scraping VRNA - 1223/1569
# scraping FND - 1224/1569
# scraping CATS - 1225/1569
# scraping WTTR - 1226/1569
# scraping TOCA - 1227/1569
# scraping CADE - 1228/1569
# scraping HCC - 1229/1569
# scraping YEXT - 1230/1569
# scraping NETS - 1231/1569
# scraping OKTA - 1232/1569
# scraping SNDR - 1233/1569
# scraping ELVT - 1234/1569
# scraping HESM - 1235/1569
# scraping APPN - 1236/1569
# scraping WOW - 1237/1569
# scraping SGH - 1238/1569
# scraping ARGX - 1239/1569
# scraping BEDU - 1240/1569
# scraping GTHX - 1241/1569
# scraping SOI - 1242/1569
# scraping ASV - 1243/1569
# scraping GDI - 1244/1569
# scraping VERI - 1245/1569
# scraping FPH - 1246/1569
# scraping GNTY - 1247/1569
# scraping NDRAU - 1248/1569
# scraping OVID - 1249/1569
# scraping URGN - 1250/1569
# scraping AMGP - 1251/1569
# scraping BHVN - 1252/1569
# scraping BY - 1253/1569
# scraping TNTR - 1254/1569
# scraping ALRN - 1255/1569
# scraping APRN - 1256/1569
# scraping DOVA - 1257/1569
# scraping MRSN - 1258/1569
# scraping ESQ - 1259/1569
# scraping ATXI - 1260/1569
# scraping GPMT - 1261/1569
# scraping SAFE - 1262/1569
# scraping SGBX - 1263/1569
# scraping ATUS - 1264/1569
# scraping BOMN - 1265/1569
# scraping ADOM - 1266/1569
# scraping ATNX - 1267/1569
# scraping PLYM - 1268/1569
# scraping IMRN - 1269/1569
# scraping SSTI - 1270/1569
# scraping NEWA - 1271/1569
# scraping RDFN - 1272/1569
# scraping SNNA - 1273/1569
# scraping RBB - 1274/1569
# scraping PETQ - 1275/1569
# scraping KALA - 1276/1569
# scraping CLXT - 1277/1569
# scraping AKCA - 1278/1569
# scraping CODX - 1279/1569
# scraping CSSE - 1280/1569
# scraping RNGR - 1281/1569
# scraping YOGA - 1282/1569
# scraping ZEAL - 1283/1569
# scraping CIFS - 1284/1569
# scraping VNTR - 1285/1569
# scraping CMTA - 1286/1569
# scraping PQG - 1287/1569
# scraping ROKU - 1288/1569
# scraping DCPH - 1289/1569
# scraping NCNA - 1290/1569
# scraping NITE - 1291/1569
# scraping RYB - 1292/1569
# scraping SECO - 1293/1569
# scraping OMP - 1294/1569
# scraping PETZ - 1295/1569
# scraping DESP - 1296/1569
# scraping BSTI - 1297/1569
# scraping CELC - 1298/1569
# scraping KRYS - 1299/1569
# scraping ZLAB - 1300/1569
# scraping IPOAU - 1301/1569
# scraping TRMT - 1302/1569
# scraping ZKIN - 1303/1569
# scraping FSCT - 1304/1569
# scraping MBIN - 1305/1569
# scraping NEXA - 1306/1569
# scraping EYE - 1307/1569
# scraping BPMP - 1308/1569
# scraping ABLX - 1309/1569
# scraping FAT - 1310/1569
# scraping LYL - 1311/1569
# scraping REDU - 1312/1569
# scraping RMBL - 1313/1569
# scraping SE - 1314/1569
# scraping MDB - 1315/1569
# scraping QD - 1316/1569
# scraping OPTN - 1317/1569
# scraping KIDS - 1318/1569
# scraping HAIR - 1319/1569
# scraping CARG - 1320/1569
# scraping SWCH - 1321/1569
# scraping RYTM - 1322/1569
# scraping BOXL - 1323/1569
# scraping RETO - 1324/1569
# scraping BXG - 1325/1569
# scraping AMRH - 1326/1569
# scraping SAIL - 1327/1569
# scraping SBT - 1328/1569
# scraping SCPH - 1329/1569
# scraping SFIX - 1330/1569
# scraping JT - 1331/1569
# scraping ASNS - 1332/1569
# scraping SEND - 1333/1569
# scraping PPDF - 1334/1569
# scraping BAND - 1335/1569
# scraping ERYP - 1336/1569
# scraping APLS - 1337/1569
# scraping SOGO - 1338/1569
# scraping MCB - 1339/1569
# scraping FEDU - 1340/1569
# scraping IFRX - 1341/1569
# scraping CBTX - 1342/1569
# scraping HX - 1343/1569
# scraping AQ - 1344/1569
# scraping ACMR - 1345/1569
# scraping SPRO - 1346/1569
# scraping ALNA - 1347/1569
# scraping AQUA - 1348/1569
# scraping FNKO - 1349/1569
# scraping ALTR - 1350/1569
# scraping LOMA - 1351/1569
# scraping ICLK - 1352/1569
# scraping LX - 1353/1569
# scraping DOGZ - 1354/1569
# scraping CASA - 1355/1569
# scraping NMRK - 1356/1569
# scraping GIG'U - 1357/1569
# scraping DNLI - 1358/1569
# scraping LBC - 1359/1569
# scraping CURO - 1360/1569
# scraping ODT - 1361/1569
# scraping QTRX - 1362/1569
# scraping AGS - 1363/1569
# scraping ARMO - 1364/1569
# scraping SLDB - 1365/1569
# scraping TORC - 1366/1569
# scraping EYEN - 1367/1569
# scraping GTES - 1368/1569
# scraping MNLO - 1369/1569
# scraping PAGS - 1370/1569
# scraping CHRA - 1470/1569
# scraping USX - 1471/1569
# scraping MGTX - 1472/1569
# scraping AMBO - 1473/1569
# scraping ADIL - 1474/1569
# scraping DAVA - 1475/1569
# scraping OPRA - 1476/1569
# scraping WISA - 1477/1569
# scraping JG - 1478/1569
# scraping LQDA - 1479/1569
# scraping TENB - 1480/1569
# scraping PDD - 1481/1569
# scraping FOCS - 1482/1569
# scraping BRY - 1483/1569
# scraping CANG - 1484/1569
# scraping AQST - 1485/1569
# scraping BE - 1486/1569
# scraping PRVB - 1487/1569
# scraping REPL - 1488/1569
# scraping ESTA - 1489/1569
# scraping CNST - 1490/1569
# scraping TLRY - 1491/1569
# scraping MYFW - 1492/1569
# scraping ALLK - 1493/1569
# scraping CRNX - 1494/1569
# scraping CCB - 1495/1569
# scraping RUBY - 1496/1569
# scraping BNGOU - 1497/1569
# scraping SFET - 1498/1569
# scraping ARDS - 1499/1569
# scraping MESA - 1500/1569
# scraping VCNX - 1501/1569
# scraping PCB - 1502/1569
# scraping ARLO - 1503/1569
# scraping SONO - 1504/1569
# scraping CWK - 1505/1569
# scraping CTK - 1506/1569
# scraping GRTS - 1507/1569
# scraping LAIX - 1508/1569
# scraping RMED - 1509/1569
# scraping STRO - 1510/1569
# scraping ARVN - 1511/1569
# scraping UROV - 1512/1569
# scraping ARCE - 1513/1569
# scraping CBNK - 1514/1569
# scraping ETTX - 1515/1569
# scraping SVMK - 1516/1569
# scraping VIOT - 1517/1569
# scraping YMAB - 1518/1569
# scraping FTCH - 1519/1569
# scraping BSVN - 1520/1569
# scraping EB - 1521/1569
# scraping ELAN - 1522/1569
# scraping XYF - 1523/1569
# scraping PRNB - 1524/1569
# scraping QTT - 1525/1569
# scraping FVCB - 1526/1569
# scraping NIO - 1527/1569
# scraping YI - 1528/1569
# scraping AXNX - 1529/1569
# scraping ORTX - 1530/1569
# scraping TWST - 1531/1569
# scraping GMDA - 1532/1569
# scraping STNE - 1533/1569
# scraping PT - 1534/1569
# scraping YETI - 1535/1569
# scraping LOGC - 1536/1569
# scraping NIU - 1537/1569
# scraping SWI - 1538/1569
# scraping MSC - 1539/1569
# scraping OSMT - 1540/1569
# scraping PHAS - 1541/1569
# scraping SIBN - 1542/1569
# scraping PLAN - 1543/1569
# scraping EQ - 1544/1569
# scraping ALLO - 1545/1569
# scraping LTHM - 1546/1569
# scraping ESTC - 1547/1569
# scraping GH - 1548/1569
# scraping KOD - 1549/1569
# scraping UPWK - 1550/1569
# scraping MDRR - 1551/1569
# scraping TLC - 1552/1569
# scraping TLSA - 1553/1569
# scraping TC - 1554/1569
# scraping WEI - 1555/1569
# scraping VAPO - 1556/1569
# scraping ETON - 1557/1569
# scraping TBLTU - 1558/1569
# scraping CNF - 1559/1569
# scraping PHCF - 1560/1569
# scraping AMTB - 1561/1569
# scraping APM - 1562/1569
# scraping QFIN - 1563/1569
# scraping LEGH - 1564/1569
# scraping TME - 1565/1569
# scraping THOR - 1566/1569
# scraping DMAC - 1567/1569
# scraping MRNA - 1568/1569
# scraping MOGU - 1569/1569

# %% [markdown]
# ## Checking companies not scraped in Yahoo Finance:

# %% [markdown]
# In this part, I will scrutinize the stocks that were nor parsed on Yahoo Finance. There could be two reasons for this - either the company is defunct (merged/was acquired or otherwise delisted from the stock exchange) or the company is still funcational but changed the ticker. In the latter case, we want to include them into our IPO list and redo the scraping from Yahoo Finance for the new ticker. <br>
#
# To check if the company is defunct, I utilize Seeking Alpha website that provides exactly the info we need.

# %%
print(f"From {len(df.Symbol)} IPO companies listed on Nasdaq, {len(notscraped)} companies were not scraped on Yahoo Finance")
# Out:
# From 1569 IPO companies listed on Nasdaq, 433 companies were not scraped on Yahoo Finance

# %%
defunct = []
newticker = []
acquired = []

url = 'https://seekingalpha.com/symbol/%s'
    
notscraped_df = pd.DataFrame()
headers = {'User-Agent' : "non-profit learning project"}

for ticker in notscraped:
    print(f'scrap - {url % ticker}')
    result = requests.get(url % ticker, headers=headers).content
    sleep(15)
    
    soup = BeautifulSoup(result)
    m = soup.find_all("div", {"class": "defunct_message defunct_message_etf"})
    l = soup.find_all("link", {"rel": "canonical"})
    if m:
        print(m)
        defunct.append(ticker)
    elif l:
        print(l)
        nt = str(l).replace('[<link href="https://seekingalpha.com/symbol/', "").replace('\" rel="canonical"/>]', '')
        newticker.append(nt)
    else:
        acquired.append(ticker)
# Out:
# scrap - https://seekingalpha.com/symbol/CTC
# [<div class="defunct_message defunct_message_etf">CTC is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/CHC
# [<div class="defunct_message defunct_message_etf">CHC is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/CLU
# [<div class="defunct_message defunct_message_etf">CLU is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/SYA
# [<div class="defunct_message defunct_message_etf">SYA is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/GRM
# [<div class="defunct_message defunct_message_etf">GRM is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/MERU
# [<div class="defunct_message defunct_message_etf">MERU is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/FNGN
# [<div class="defunct_message defunct_message_etf">FNGN is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/CRU
# [<div class="defunct_message defunct_message_etf">CRU is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/BALT
# [<div class="defunct_message defunct_message_etf">BALT is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/PNG
# [<div class="defunct_message defunct_message_etf">PNG is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/CNVO
# [<div class="defunct_message defunct_message_etf">CNVO is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/EXL
# [<div class="defunct_message defunct_message_etf">EXL is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/GGS
# [<link href="https://seekingalpha.com/symbol/GEGSQ" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/MITL
# [<link href="https://seekingalpha.com/symbol/MITL" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/DHRM
# [<link href="https://seekingalpha.com/symbol/LLIT" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/DVOX
# scrap - https://seekingalpha.com/symbol/RLOC
# [<div class="defunct_message defunct_message_etf">RLOC is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/AH
# scrap - https://seekingalpha.com/symbol/TNGN
# scrap - https://seekingalpha.com/symbol/NOR
# [<link href="https://seekingalpha.com/symbol/NORNQ" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/KONE
# [<div class="defunct_message defunct_message_etf">KONE is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/NKA
# [<div class="defunct_message defunct_message_etf">NKA is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/CHRM
# [<div class="defunct_message defunct_message_etf">CHRM is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/SANWU
# [<link href="https://seekingalpha.com/symbol/SANW" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/HSFT
# [<div class="defunct_message defunct_message_etf">PACT is defunct since March 28, 2014. Acquired by BCP (Singapore) VI Cayman Acquisition Co. Ltd. ($7.30/sh)</div>]
# scrap - https://seekingalpha.com/symbol/VRNGU
# scrap - https://seekingalpha.com/symbol/MOTR
# [<link href="https://seekingalpha.com/symbol/VLTC" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol
is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/MKTG
# [<div class="defunct_message defunct_message_etf">MKTG is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/TLLP
# [<link href="https://seekingalpha.com/symbol/ANDX" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/MNEL
# [<div class="defunct_message defunct_message_etf">MNEL is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/SGNT
# [<div class="defunct_message defunct_message_etf">SGNT is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/STIR
# [<link href="https://seekingalpha.com/symbol/STIR" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/TEU
# [<div class="defunct_message defunct_message_etf">TEU is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/TMS
# [<div class="defunct_message defunct_message_etf">TMS is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/ZIP
# [<div class="defunct_message defunct_message_etf">ZIP is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/MDGN
# [<link href="https://seekingalpha.com/symbol/GNMX" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/TZYM
# scrap - https://seekingalpha.com/symbol/SZYM
# scrap - https://seekingalpha.com/symbol/FSL
# [<div class="defunct_message defunct_message_etf">FSL is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/LPR
# scrap - https://seekingalpha.com/symbol/ACTV
# [<div class="defunct_message defunct_message_etf">ACTV is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/LNKD
# [<link href="https://seekingalpha.com/symbol/MSFT" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/ZX
# [<link href="https://seekingalpha.com/symbol/ZXAIY" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/FFN
# scrap - https://seekingalpha.com/symbol/DATE
# scrap - https://seekingalpha.com/symbol/NQ
# scrap - https://seekingalpha.com/symbol/RPXC
# [<div class="defunct_message defunct_message_etf">RPXC is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/FBNK
# [<link href="https://seekingalpha.com/symbol/FBNK" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/AWAY
# [<div class="defunct_message defunct_message_etf">AWAY is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/KIOR
# [<div class="defunct_message defunct_message_etf">KIOR is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/VHS
# [<div class="defunct_message defunct_message_etf">VHS is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/RATE
# [<div class="defunct_message defunct_message_etf">RATE is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/GSJK
# [<link href="https://seekingalpha.com/symbol/CCLP" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/P
# [<link href="https://seekingalpha.com/symbol/P" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/FIO
# [<div class="defunct_message defunct_message_etf">FIO is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/TAOM
# [<div class="defunct_message defunct_message_etf">TAOM is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/CJES
# [<link href="https://seekingalpha.com/symbol/CJ" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/TEA
# [<div class="defunct_message defunct_message_etf">TEA is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/AMTG
# [<div class="defunct_message defunct_message_etf">AMTG is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/SKUL
# [<div class="defunct_message defunct_message_etf">SKUL is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/TNGO
# [<link href="https://seekingalpha.com/symbol/TNGO" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/OILT
# [<div class="defunct_message defunct_message_etf">OILT is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/TUDO
# [<div class="defunct_message defunct_message_etf">TUDO is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/MTGE
# [<div class="defunct_message defunct_message_etf">MTGE is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/PBSK
# [<link href="https://seekingalpha.com/symbol/PBSK" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/ZLTQ
# [<div class="defunct_message defunct_message_etf">ZLTQ is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/DDMG
# scrap - https://seekingalpha.com/symbol/MFRM
# [<div class="defunct_message defunct_message_etf">MFRM is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/INVN
# scrap - https://seekingalpha.com/symbol/LRE
# scrap - https://seekingalpha.com/symbol/IMPV
# [<link href="https://seekingalpha.com/symbol/IMPV" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/RNF
# [<div class="defunct_message defunct_message_etf">RNF is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/NDRO
# [<div class="defunct_message defunct_message_etf">NDRO-OLD is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/NRGM
# scrap - https://seekingalpha.com/symbol/KORS
# scrap - https://seekingalpha.com/symbol/GZT
# scrap - https://seekingalpha.com/symbol/SN
# scrap - https://seekingalpha.com/symbol/JIVE
# [<div class="defunct_message defunct_message_etf">JIVE is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/RRMS
# [<div class="defunct_message defunct_message_etf">RRMS is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/MEMP
# [<div class="defunct_message defunct_message_etf">MEMP is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/HLSS
# [<div class="defunct_message defunct_message_etf">HLSS is defunct since April 29, 2015. Delisted following merger with NRZ</div>]
# scrap - https://seekingalpha.com/symbol/CERE
# [<div class="defunct_message defunct_message_etf">CERE is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/GSE
# [<div class="defunct_message defunct_message_etf">GSE is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/FX
# [<div class="defunct_message defunct_message_etf">FX is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/RNDY
# [<div class="defunct_message defunct_message_etf">RNDY is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/CEMP
# [<div class="defunct_message defunct_message_etf">CEMP is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/AVG
# [<div class="defunct_message defunct_message_etf">AVG is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/GWAY
# [<div class="defunct_message defunct_message_etf">GWAY is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/MM
# [<div class="defunct_message defunct_message_etf">MM is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/PRSS
# [<link href="https://seekingalpha.com/symbol/PRSS" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/BNNY
# [<div class="defunct_message defunct_message_etf">BNNY is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/WHZ
# [<link href="https://seekingalpha.com/symbol/WHZT" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/DWRE
# [<div class="defunct_message defunct_message_etf">DWRE is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/NSM
# [<div class="defunct_message defunct_message_etf">NSM is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/SIR
# [<link href="https://seekingalpha.com/symbol/SIR" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/EDG
# [<div class="defunct_message defunct_message_etf">EDG is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/ENVI
# [<div class="defunct_message defunct_message_etf">ENVI is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/BLOX
# [<div class="defunct_message defunct_message_etf">BLOX is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/TUMI
# [<div class="defunct_message defunct_message_etf">TUMI is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/DCIN
# [<div class="defunct_message defunct_message_etf">DCIN is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/EAC
# [<div class="defunct_message defunct_message_etf">EAC is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/EVAC
# [<div class="defunct_message defunct_message_etf">EVAC is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/IRG
# [<div class="defunct_message defunct_message_etf">IRG is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/ADNC
# [<div class="defunct_message defunct_message_etf">ADNC is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/PDH
# [<div class="defunct_message defunct_message_etf">PDH is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/TSRO
# [<link href="https://seekingalpha.com/symbol/TSRO" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/EXA
# [<div class="defunct_message defunct_message_etf">EXA is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/CNCO
# [<div class="defunct_message defunct_message_etf">CNCO is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/AMRE
# [<div class="defunct_message defunct_message_etf">AMRE is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/EOPN
# [<div class="defunct_message defunct_message_etf">EOPN is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/HPTX
# [<div class="defunct_message defunct_message_etf">HPTX is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/NTI
# [<div class="defunct_message defunct_message_etf">NTI is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/KYAK
# [<div class="defunct_message defunct_message_etf">KYAK is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/DRTX
# [<div class="defunct_message defunct_message_etf">DRTX is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/PSMI
# [<div class="defunct_message defunct_message_etf">PSMI is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/ELOQ
# [<div class="defunct_message defunct_message_etf">ELOQ is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/CBF
# [<div class="defunct_message defunct_message_etf">CBF is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/SUSP
# [<link href="https://seekingalpha.com/symbol/SUN" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/TRLA
# [<link href="https://seekingalpha.com/symbol/Z" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/WWAV
# [<div class="defunct_message defunct_message_etf">WWAV is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/MEILU
# [<link href="https://seekingalpha.com/symbol/MEIL" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/LGP
# [<link href="https://seekingalpha.com/symbol/CAPL" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/LNCO
# [<link href="https://seekingalpha.com/symbol/LNCOQ" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/KYTH
# [<div class="defunct_message defunct_message_etf">KYTH is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/FLTX
# [<div class="defunct_message defunct_message_etf">FLTX is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/LOCK
# [<div class="defunct_message defunct_message_etf">LOCK is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/JMI
# [<div class="defunct_message defunct_message_etf">JMI is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/ALDW
# [<div class="defunct_message defunct_message_etf">ALDW is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/RKUS
# [<div class="defunct_message defunct_message_etf">RKUS is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/SXE
# [<div class="defunct_message defunct_message_etf">SXE is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/SBY
# [<div class="defunct_message defunct_message_etf">SBY is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/SCTY
# [<link href="https://seekingalpha.com/symbol/TSLA" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/WGP
# scrap - https://seekingalpha.com/symbol/KBIO
# scrap - https://seekingalpha.com/symbol/LPDX
# scrap - https://seekingalpha.com/symbol/CVRR
# scrap - https://seekingalpha.com/symbol/XOOM
# [<div class="defunct_message defunct_message_etf">XOOM is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/NSLP
# scrap - https://seekingalpha.com/symbol/ZFC
# [<div class="defunct_message defunct_message_etf">ZFC is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/PF
# [<link href="https://seekingalpha.com/symbol/PF" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/NVEEU
# scrap - https://seekingalpha.com/symbol/WSTC
# [<div class="defunct_message defunct_message_etf">WSTC is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/AVIV
# [<div class="defunct_message defunct_message_etf">AVIV is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/SSNI
# [<div class="defunct_message defunct_message_etf">SSNI is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/HAWK
# [<div class="defunct_message defunct_message_etf">HAWK is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/TAM
# [<div class="defunct_message defunct_message_etf">TAM is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/FWM
# [<div class="defunct_message defunct_message_etf">FWM is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/RALY
# [<div class="defunct_message defunct_message_etf">RALY is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/OMTH
# [<div class="defunct_message defunct_message_etf">OMTH is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/PGEM
# [<div class="defunct_message defunct_message_etf">PGEM is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/ADHD
# [<link href="https://seekingalpha.com/symbol/ARCT" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/MKTO
# [<div class="defunct_message defunct_message_etf">MKTO is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/AMBI
# [<div class="defunct_message defunct_message_etf">AMBI is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/UBIC
# [<link href="https://seekingalpha.com/symbol/FTEO" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/TEP
# [<link href="https://seekingalpha.com/symbol/TGE" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/NBCB
# scrap - https://seekingalpha.com/symbol/BIOAU
# scrap - https://seekingalpha.com/symbol/CYNI
# scrap - https://seekingalpha.com/symbol/ARPI
# scrap - https://seekingalpha.com/symbol/Q
# [<link href="https://seekingalpha.com/symbol/IQV" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/RCPT
# [<link href="https://seekingalpha.com/symbol/CELG" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/RNA
# [<div class="defunct_message defunct_message_etf">RNA is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/TRMR
# [<link href="https://seekingalpha.com/symbol/TLRA" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/GIMO
# [<div class="defunct_message defunct_message_etf">GIMO is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/TXTR
# [<div class="defunct_message defunct_message_etf">TXTR is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/RCAP
# [<div class="defunct_message defunct_message_etf">RCAP is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/FISH
# [<div class="defunct_message defunct_message_etf">AZUR is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/LIQD
# [<link href="https://seekingalpha.com/symbol/LIQD" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/WCIC
# [<div class="defunct_message defunct_message_etf">WCIC is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/ICEL
# [<div class="defunct_message defunct_message_etf">ICEL is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/XGTI
# [<div class="defunct_message defunct_message_etf">XGTI-OLD is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/DRII
# [<div class="defunct_message defunct_message_etf">DRII is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/UCP
# [<div class="defunct_message defunct_message_etf">UCP is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/NYLD
# [<link href="https://seekingalpha.com/symbol/CWEN" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/RGDO
# scrap - https://seekingalpha.com/symbol/EVHC
# scrap - https://seekingalpha.com/symbol/CCCR
# scrap - https://seekingalpha.com/symbol/QEPM
# scrap - https://seekingalpha.com/symbol/STCK
# scrap - https://seekingalpha.com/symbol/CVT
# scrap - https://seekingalpha.com/symbol/WPT
# scrap - https://seekingalpha.com/symbol/YUME
# scrap - https://seekingalpha.com/symbol/ATHL
# [<div class="defunct_message defunct_message_etf">ATHL is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/ENZY
# [<div class="defunct_message defunct_message_etf">ENZY is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/VMEM
# [<div class="defunct_message defunct_message_etf">VMEM is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/MONT
# [<div class="defunct_message defunct_message_etf">MONT is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/COVS
# [<div class="defunct_message defunct_message_etf">COVS is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/FMI
# [<div class="defunct_message defunct_message_etf">FMI is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/MYCC
# [<div class="defunct_message defunct_message_etf">MYCC is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/FUEL
# [<div class="defunct_message defunct_message_etf">FUEL is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/OCIR
# [<link href="https://seekingalpha.com/symbol/CINR" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/SCAI
# [<div class="defunct_message defunct_message_etf">SCAI is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/ABGB
# [<link href="https://seekingalpha.com/symbol/ABGOF" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/SGM
# [<div class="defunct_message defunct_message_etf">SGM is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/WNRL
# [<div class="defunct_message defunct_message_etf">WNRL is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/LDRH
# [<div class="defunct_message defunct_message_etf">LDRH is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/SFXE
# [<div class="defunct_message defunct_message_etf">SFXE is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/OCIP
# [<div class="defunct_message defunct_message_etf">OCIP is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/GOMO
# [<div class="defunct_message defunct_message_etf">GOMO is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/ZU
# [<div class="defunct_message defunct_message_etf">ZU is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/RLYP
# [<div class="defunct_message defunct_message_etf">RLYP is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/JGW
# [<link href="https://seekingalpha.com/symbol/JGWEQ" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/MEP
# [<div class="defunct_message defunct_message_etf">MEP is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/MVNR
# [<div class="defunct_message defunct_message_etf">MVNR is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/NCFT
# [<div class="defunct_message defunct_message_etf">NCFT is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/CUDA
# [<div class="defunct_message defunct_message_etf">CUDA is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/QUNR
# [<div class="defunct_message defunct_message_etf">QUNR is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/CQH
# [<link href="https://seekingalpha.com/symbol/CQH" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/NMBL
# [<div class="defunct_message defunct_message_etf">NMBL is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/FGL
# [<link href="https://seekingalpha.com/symbol/FG" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/VLP
# [<link href="https://seekingalpha.com/symbol/VLP" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/KFX
# [<div class="defunct_message defunct_message_etf">KFX is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/SNOW
# [<div class="defunct_message defunct_message_etf">SNOW is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/CLDN
# [<link href="https://seekingalpha.com/symbol/EIGR" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/NADL
# [<div class="defunct_message defunct_message_etf">NADL is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/RSPP
# [<div class="defunct_message defunct_message_etf">RSPP is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/HELI
# scrap - https://seekingalpha.com/symbol/LMNS
# scrap - https://seekingalpha.com/symbol/AMDA
# scrap - https://seekingalpha.com/symbol/TLMR
# scrap - https://seekingalpha.com/symbol/NRX
# [<link href="https://seekingalpha.com/symbol/NRXGQ" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/ARGS
# [<link href="https://seekingalpha.com/symbol/ARGSQ" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/EBIO
# [<link href="https://seekingalpha.com/symbol/SESN" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/EGLT
# [<link href="https://seekingalpha.com/symbol/EGLT" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/ASPX
# [<div class="defunct_message defunct_message_etf">ASPX is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/CBSO
# [<link href="https://seekingalpha.com/symbol/OUT" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/EVDY
# [<div class="defunct_message defunct_message_etf">EVDY is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/SQBK
# [<div class="defunct_message defunct_message_etf">SQBK is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/KING
# [<div class="defunct_message defunct_message_etf">KING is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/NORD
# [<div class="defunct_message defunct_message_etf">NORD is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/BRDR
# [<div class="defunct_message defunct_message_etf">BRDR is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/RTGN
# [<link href="https://seekingalpha.com/symbol/PULM" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/RXDX
# [<div class="defunct_message defunct_message_etf">RXDX is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/EVAR
# [<div class="defunct_message defunct_message_etf">EVAR is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/VGGL
# [<div class="defunct_message defunct_message_etf">DDAY is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/QTNTU
# [<link href="https://seekingalpha.com/symbol/QTNT" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/TRIV
# [<div class="defunct_message defunct_message_etf">TRIV is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/ZOES
# [<link href="https://seekingalpha.com/symbol/ZOES" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/CERU
# [<link href="https://seekingalpha.com/symbol/DARE" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/SYRX
# [<link href="https://seekingalpha.com/symbol/INPX" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/KANG
# [<link href="https://seekingalpha.com/symbol/KANG" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/LQ
# [<div class="defunct_message defunct_message_etf">LQ is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/OPWR
# [<div class="defunct_message defunct_message_etf">OPWR is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/IMS
# [<link href="https://seekingalpha.com/symbol/IQV" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/CORI
# [<link href="https://seekingalpha.com/symbol/CORI" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/SEMI
# [<div class="defunct_message defunct_message_etf">SEMI is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/KTWO
# [<link href="https://seekingalpha.com/symbol/KTWO" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/MOKO
# [<div class="defunct_message defunct_message_etf">MOKO is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/TCPI
# [<div class="defunct_message defunct_message_etf">TCPI is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/IMPR
# [<div class="defunct_message defunct_message_etf">IMPR is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/ADPT
# [<div class="defunct_message defunct_message_etf">ADPT is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/ECR
# [<div class="defunct_message defunct_message_etf">ECR-OLD is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/KITE
# [<div class="defunct_message defunct_message_etf">KITE is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/MRKT
# [<link href="https://seekingalpha.com/symbol/INFO" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/ZSPH
# [<div class="defunct_message defunct_message_etf">ZSPH is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/PARN
# [<link href="https://seekingalpha.com/symbol/PARNF" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/ABY
# [<link href="https://seekingalpha.com/symbol/AY" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/MRD
# [<div class="defunct_message defunct_message_etf">MRD is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/ZPIN
# [<div class="defunct_message defunct_message_etf">ZPIN is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/AAVL
# [<link href="https://seekingalpha.com/symbol/ADVM" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/RIGP
# [<div class="defunct_message defunct_message_etf">RIGP is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/CFRXU
# scrap - https://seekingalpha.com/symbol/INNL
# [<div class="defunct_message defunct_message_etf">INNL is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/TUBE
# [<div class="defunct_message defunct_message_etf">TUBE is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/ROKA
# [<div class="defunct_message defunct_message_etf">ROKA is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/GBIM
# [<link href="https://seekingalpha.com/symbol/GBIM" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/BNK
# [<div class="defunct_message defunct_message_etf">BNK is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/GNBC
# [<link href="https://seekingalpha.com/symbol/GNBC" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/DSKY
# [<div class="defunct_message defunct_message_etf">DSKY is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/FCB
# [<link href="https://seekingalpha.com/symbol/FCB" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/LOXO
# [<link href="https://seekingalpha.com/symbol/LOXO" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/MBLY
# [<div class="defunct_message defunct_message_etf">MBLY is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/VTTI
# [<div class="defunct_message defunct_message_etf">VTTI is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/CNNX
# [<link href="https://seekingalpha.com/symbol/CNXM" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/VTAE
# [<div class="defunct_message defunct_message_etf">VTAE is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/TKAI
# [<link href="https://seekingalpha.com/symbol/NVUS" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/CIVI
# [<link href="https://seekingalpha.com/symbol/CIVI" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/ABCW
# scrap - https://seekingalpha.com/symbol/DM
# [<link href="https://seekingalpha.com/symbol/DM" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/GBSN
# scrap - https://seekingalpha.com/symbol/MOLG
# scrap - https://seekingalpha.com/symbol/YDLE
# [<div class="defunct_message defunct_message_etf">YDLE is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/JPEP
# [<div class="defunct_message defunct_message_etf">JPEP is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/VWR
# [<div class="defunct_message defunct_message_etf">VWR is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/NEFF
# [<div class="defunct_message defunct_message_etf">NEFF is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/NEOT
# [<link href="https://seekingalpha.com/symbol/EVFM" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/CNV
# [<link href="https://seekingalpha.com/symbol/CNVAF" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/NDRM
# [<div class="defunct_message defunct_message_etf">NDRM is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/VA
# [<div class="defunct_message defunct_message_etf">VA is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/NAP
# [<link href="https://seekingalpha.com/symbol/NAP" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/CAPN
# [<div class="defunct_message defunct_message_etf">CAPN is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/INCR
# [<link href="https://seekingalpha.com/symbol/SYNH" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/SNC
# [<div class="defunct_message defunct_message_etf">SNC is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/JUNO
# [<div class="defunct_message defunct_message_etf">JUNO is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/MDVXU
# scrap - https://seekingalpha.com/symbol/RMP
# scrap - https://seekingalpha.com/symbol/MPG
# scrap - https://seekingalpha.com/symbol/CNXR
# scrap - https://seekingalpha.com/symbol/HDP
# [<link href="https://seekingalpha.com/symbol/HDP" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/AVOL
# [<div class="defunct_message defunct_message_etf">AVOL is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/ENTL
# [<div class="defunct_message defunct_message_etf">ENTL is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/PN
# [<div class="defunct_message defunct_message_etf">PN is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/CHEKU
# [<link href="https://seekingalpha.com/symbol/CHEK" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/ITEK
# [<link href="https://seekingalpha.com/symbol/RCKT" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/AVNU
# [<div class="defunct_message defunct_message_etf">AVNU is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/CPPL
# [<div class="defunct_message defunct_message_etf">CPPL is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/NVET
# [<div class="defunct_message defunct_message_etf">NVET is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/STDY
# [<link href="https://seekingalpha.com/symbol/STDY" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/MXPT
# [<div class="defunct_message defunct_message_etf">MXPT is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/APIC
# [<div class="defunct_message defunct_message_etf">APIC is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/WOWO
# [<link href="https://seekingalpha.com/symbol/JMU" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/PGND
# [<div class="defunct_message defunct_message_etf">PGND is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/BKFS
# [<div class="defunct_message defunct_message_etf">BKFS is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/CDRB
# [<div class="defunct_message defunct_message_etf">CDRB is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/FENX
# [<link href="https://seekingalpha.com/symbol/FENX" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/EQGP
# [<link href="https://seekingalpha.com/symbol/EQGP" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/BOJA
# [<link href="https://seekingalpha.com/symbol/BOJA" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/TEGP
# scrap - https://seekingalpha.com/symbol/CLCD
# scrap - https://seekingalpha.com/symbol/XTLY
# scrap - https://seekingalpha.com/symbol/YECO
# scrap - https://seekingalpha.com/symbol/GNRT
# [<div class="defunct_message defunct_message_etf">GNRT is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/MB
# [<link href="https://seekingalpha.com/symbol/MB" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/CAFD
# [<div class="defunct_message defunct_message_etf">CAFD is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/FOGO
# [<div class="defunct_message defunct_message_etf">FOGO is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/NVLS
# [<link href="https://seekingalpha.com/symbol/ALPN" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/IVTY
# [<link href="https://seekingalpha.com/symbol/IVTY" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/AXON
# [<div class="defunct_message defunct_message_etf">AXON-OLD is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/BITI
# [<div class="defunct_message defunct_message_etf">BITI is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/GI
# [<div class="defunct_message defunct_message_etf">GI is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/PTXP
# [<div class="defunct_message defunct_message_etf">PTXP is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/GLBL
# [<div class="defunct_message defunct_message_etf">GLBL is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/BUFF
# [<div class="defunct_message defunct_message_etf">BUFF is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/CNXC
# [<div class="defunct_message defunct_message_etf">CNXC is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/BETR
# [<div class="defunct_message defunct_message_etf">BETR is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/LMFAU
# scrap - https://seekingalpha.com/symbol/MPSX
# [<div class="defunct_message defunct_message_etf">MPSX is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/DMTX
# [<div class="defunct_message defunct_message_etf">DMTX is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/AFCO
# [<link href="https://seekingalpha.com/symbol/FPI" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/CERCU
# scrap - https://seekingalpha.com/symbol/MIRN
# [<link href="https://seekingalpha.com/symbol/SYBX" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/AAAP
# [<div class="defunct_message defunct_message_etf">AAAP is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/AVXS
# [<div class="defunct_message defunct_message_etf">AVXS is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/PAVMU
# scrap - https://seekingalpha.com/symbol/COTV
# [<div class="defunct_message defunct_message_etf">COTV is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/PZRX
# [<div class="defunct_message defunct_message_etf">PZRX is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/ONSIU
# scrap - https://seekingalpha.com/symbol/PBNC
# [<link href="https://seekingalpha.com/symbol/PBNC" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/SRTSU
# scrap - https://seekingalpha.com/symbol/LTEA
# [<link href="https://seekingalpha.com/symbol/LBCC" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/PTHN
# [<div class="defunct_message defunct_message_etf">PTHN is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/APFH
# [<div class="defunct_message defunct_message_etf">APFH is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/MSDI
# [<link href="https://seekingalpha.com/symbol/INNT" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/ATMR
# [<link href="https://seekingalpha.com/symbol/ATOM" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/APTI
# [<link href="https://seekingalpha.com/symbol/APTI" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/AMMA
# [<div class="defunct_message defunct_message_etf">AMMA-OLD is defunct.</div>]
# scrap - https://seekingalpha.com/symbol/TIG
# scrap - https://seekingalpha.com/symbol/WRD
# [<link href="https://seekingalpha.com/symbol/WRD" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/MULE
# scrap - https://seekingalpha.com/symbol/NDRAU
# scrap - https://seekingalpha.com/symbol/TNTR
# scrap - https://seekingalpha.com/symbol/BSTI
# scrap - https://seekingalpha.com/symbol/IPOAU
# scrap - https://seekingalpha.com/symbol/ABLX
# scrap - https://seekingalpha.com/symbol/SEND
# [<link href="https://seekingalpha.com/symbol/SEND" rel="canonical"/>]
# scrap - https://seekingalpha.com/symbol/GIG'U
# scrap - https://seekingalpha.com/symbol/ARMO
# [<div class="defunct_message defunct_message_etf">ARMO is defunct since January  1, 2019. Merged</div>]
# scrap - https://seekingalpha.com/symbol/XSPL
# scrap - https://seekingalpha.com/symbol/BNGOU

# %%
print(f"from {len(df.Symbol)} IPO companies listed on Nasdaq, {len(defunct)} companies are defunct as of May 2019, {len(acquired)} were probably acquired and {len(newticker)} changed their ticker")
# Out:
# from 1569 IPO companies listed on Nasdaq, 215 companies are defunct as of May 2019, 124 were probably acquired and 94 changed their ticker

# %%
acquired
# Out:
# ['DVOX',
#  'AH',
#  'TNGN',
#  'VRNGU',
#  'BSFT',
#  'CHKM',
#  'MCP',
#  'CIS',
#  'OINK',
#  'QLIK',
#  'RLD',
#  'SMT',
#  'OXF',
#  'AMAP',
#  'KH',
#  'IL',
#  'PATH',
#  'DMED',
#  'TSRX',
#  'ELT',
#  'RNO',
#  'CCSC',
#  'GAGA',
#  'EXAM',
#  'MCOX',
#  'AEGR',
#  'BBRG',
#  'XRS',
#  'SHP',
#  'NTSP',
#  'BODY',
#  'CCG',
#  'GEDU',
#  'ANAC',
#  'SYSW',
#  'XNY',
#  'ARX',
#  'LZEN',
#  'KFFG',
#  'TFM',
#  'CTE',
#  'SODA',
#  'XUE',
#  'SPBC',
#  'QRE',
#  'SWFT',
#  'ISS',
#  'LAS',
#  'MOBI',
#  'BONA',
#  'CTP',
#  'YOKU',
#  'FXCM',
#  'BCDS',
#  'VELT',
#  'DMD',
#  'ZA',
#  'KIPS',
#  'IFT',
#  'ECYT',
#  'TBOW',
#  'EPOC',
#  'TZYM',
#  'SZYM',
#  'LPR',
#  'FFN',
#  'DATE',
#  'NQ',
#  'DDMG',
#  'INVN',
#  'LRE',
#  'NRGM',
#  'KORS',
#  'GZT',
#  'SN',
#  'WGP',
#  'KBIO',
#  'LPDX',
#  'CVRR',
#  'NSLP',
#  'NVEEU',
#  'NBCB',
#  'BIOAU',
#  'CYNI',
#  'ARPI',
#  'RGDO',
#  'EVHC',
#  'CCCR',
#  'QEPM',
#  'STCK',
#  'CVT',
#  'WPT',
#  'YUME',
#  'HELI',
#  'LMNS',
#  'AMDA',
#  'TLMR',
#  'CFRXU',
#  'ABCW',
#  'GBSN',
#  'MOLG',
#  'MDVXU',
#  'RMP',
#  'MPG',
#  'CNXR',
#  'TEGP',
#  'CLCD',
#  'XTLY',
#  'YECO',
#  'LMFAU',
#  'CERCU',
#  'PAVMU',
#  'ONSIU',
#  'SRTSU',
#  'TIG',
#  'MULE',
#  'NDRAU',
#  'TNTR',
#  'BSTI',
#  'IPOAU',
#  'ABLX',
#  "GIG'U",
#  'XSPL',
#  'BNGOU']

# %%
sorted(defunct)
df[df['Symbol'].isin(defunct)]
# Out:
#                                      Company Name Symbol  \
# 0                             IFM INVESTMENTS LTD    CTC
# 2                        CHINA HYDROELECTRIC CORP    CHC
# 4                     CELLU TISSUE HOLDINGS, INC.    CLU
# 5                          SYMETRA FINANCIAL CORP    SYA
# 7                        GRAHAM PACKAGING CO INC.    GRM
# 12                              MERU NETWORKS INC   MERU
# 20                         FINANCIAL ENGINES, LLC   FNGN
# 21                           CRUDE CARRIERS CORP.    CRU
# 24                             BALTIC TRADING LTD   BALT
# 26                     PAA NATURAL GAS STORAGE LP    PNG
# 27                                   CONVIO, INC.   CNVO
# 29                              EXCEL TRUST, INC.    EXL
# 37                                 REACHLOCAL INC   RLOC
# 46                       LUOKUNG TECHNOLOGY CORP.   KONE
# 50                 NISKA GAS STORAGE PARTNERS LLC    NKA
# 51                      CHARM COMMUNICATIONS INC.   CHRM
# 54          PACTERA TECHNOLOGY INTERNATIONAL LTD.   HSFT
# 80                    MEDIAMIND TECHNOLOGIES INC.   MDMD
# 92                                   SCIQUEST INC    SQI
# 141                       FORTEGRA FINANCIAL CORP    FRF
# 152                E-COMMERCE CHINA DANGDANG INC.   DANG
# 183                   QIHOO 360 TECHNOLOGY CO LTD   QIHU
# 188                       FRANKLIN FINANCIAL CORP   FRNK
# 189                                 RESPONSYS INC   MKTG
# 192                         MISSION NEWENERGY LTD   MNEL
# 193                  SAGENT PHARMACEUTICALS, INC.   SGNT
# 198                                BOX SHIPS INC.    TEU
# 200                       TMS INTERNATIONAL CORP.    TMS
# TRNO         15.330121     19.530001        0.190001         64300.0
#
#       inweek_adjclose  inweek_open  inweek_spread  inweek_volume
# AMCF         5.830000     6.030000       0.280000       106300.0
# CHSP        11.927483    18.910000       0.139999        75900.0
# GNRC         8.612183    13.050000       0.290000       110000.0
# QNST        12.980000    13.500000       0.809999       504000.0
# TRNO        14.770803    18.809999       0.199999        91200.0

# %%
df_yahoo.shape
# Out:
# (1136, 12)

# %% [markdown]
# ## Joining two dataframes - from NASDAQ and from Yahoo Finance:

# %%
df.index = df.Symbol

# %%
df_ipo = df.join(df_yahoo, how='inner')
df_ipo.head()
# Out:
#                                  Company Name Symbol                   Market  \
# AMCF  ANDATEE CHINA MARINE FUEL SERVICES CORP   AMCF                   NASDAQ
# CHSP                 CHESAPEAKE LODGING TRUST   CHSP  New York Stock Exchange
# GNRC                    GENERAC HOLDINGS INC.   GNRC  New York Stock Exchange
# QNST                          QUINSTREET, INC   QNST                   NASDAQ
# TRNO                      TERRENO REALTY CORP   TRNO  New York Stock Exchange
#
#       Price      Shares  Offer Amount Date Priced  employees  \
# AMCF    6.3   3134921.0    19750002.0  2010-01-26      128.0
# CHSP   20.0   7500000.0   150000000.0  2010-01-22        3.0
# GNRC   13.0  18750000.0   243750000.0  2010-02-11     1486.0
# QNST   15.0  10000000.0   150000000.0  2010-02-11      568.0
# TRNO   20.0   8750000.0   175000000.0  2010-02-10        6.0
#
#                                                 address US_state  ...  \
# AMCF  NO. 68 BINHAI RD DALIAN XIGANG DISTRICTDALIAN ...      NaN  ...
# CHSP  4300 WILSON BOULEVARDSUITE 625ARLINGTON, VA 22203       VA  ...
# GNRC            S45 W29290 HIGHWAY 59WAUKESHA, WI 53187       WI  ...
# QNST     950 TOWER LANE, 6TH FLOORFOSTER CITY, CA 94404       CA  ...
# TRNO   16 MAIDEN LANEFIFTH FLOORSAN FRANCISCO, CA 94108       CA  ...
#
#      firstday_spread firstday_volume inmonth_adjclose  inmonth_open  \
# AMCF        0.790000       1113500.0         7.590000      8.000000
# CHSP        0.150002        153200.0        12.508080     19.400000
# GNRC        0.850000       9627100.0         9.719180     14.910000
# QNST        0.700000       5815700.0        16.410000     16.010000
# TRNO        0.420000       4515300.0        15.330121     19.530001
#
#       inmonth_spread  inmonth_volume  inweek_adjclose  inweek_open  \
# AMCF        0.790000        323300.0         5.830000     6.030000
# CHSP        0.510000         40500.0        11.927483    18.910000
# GNRC        0.929999        265400.0         8.612183    13.050000
# QNST        0.749999         27300.0        12.980000    13.500000
# TRNO        0.190001         64300.0        14.770803    18.809999
#
#       inweek_spread  inweek_volume
# AMCF       0.280000       106300.0
# CHSP       0.139999        75900.0
# GNRC       0.290000       110000.0
# QNST       0.809999       504000.0
# TRNO       0.199999        91200.0
#
# [5 rows x 25 columns]

# %%
df_ipo.shape
# Out:
# (1136, 25)

# %%
df_ipo.to_csv('ipo_stock_2010_2018.csv', index=False)

# %% [markdown]
# ## 1.2. Scraping profile and industry from Yahoo Finance

# %% [markdown]
# In this step, I scrape sector, industry, employees as of now, if available CEO pay and CEO year born from Yahoo Finance.

# %%
sector = []
industry = []
employees2019 = []
CEO_pay = []
CEO_born = []

url_1 = 'https://finance.yahoo.com/quote/%s/'
url_2 = 'profile?p=%s'

for i, ticker in enumerate(df_ipo.Symbol):
    print(f"scraping {ticker} - {i+1}/{len(df_ipo.Symbol)}")
    result = requests.get(url_1 % ticker + url_2 % ticker)
    content = result.content

    soup = BeautifulSoup(content)
    data = soup.find_all('span', {"class":"Fw(600)"})
    if data:
        txt = [x.get_text() for x in data]
        sector.append(txt[0])
        industry.append(txt[1])
        employees2019.append(txt[2])

    else:
        sector.append(np.nan)
        industry.append(np.nan)
        employees2019.append(np.nan)
    
    try:
        table = pd.read_html(content)[0]
        #checking if table has CEO 
        if ('Title' in table) and (table['Title'].str.contains('CEO').sum() == 1):
            CEO_pay.append(table['Pay'][table['Title'].str.contains('CEO')].values[0]) 
            CEO_born.append(table['Year Born'][table['Title'].str.contains('CEO')].values[0])
        else:
            CEO_pay.append(np.nan) 
            CEO_born.append(np.nan)

    except ValueError:
        CEO_pay.append(np.nan) 
        CEO_born.append(np.nan)
    
print(f"checking lengths sector: {len(sector)}, industry: {len(industry)}, employees2019: {len(employees2019)}, CEO pay: {len(CEO_pay)}, CEO_born: {len(CEO_born)}")
# Out:
# scraping AMCF - 1/1136
# scraping CHSP - 2/1136
# scraping GNRC - 3/1136
# scraping QNST - 4/1136
# scraping TRNO - 5/1136
# scraping PDM - 6/1136
# scraping IRWD - 7/1136
# scraping SSNC - 8/1136
# scraping STNG - 9/1136
# scraping HTHT - 10/1136
# scraping CRMD - 11/1136
# scraping FIBK - 12/1136
# scraping CALX - 13/1136
# scraping MXL - 14/1136
# scraping AVEO - 15/1136
# scraping ST - 16/1136
# scraping ANTH - 17/1136
# scraping AOSL - 18/1136
# scraping CDXS - 19/1136
# scraping ALIM - 20/1136
# scraping SPSC - 21/1136
# scraping CLDT - 22/1136
# scraping MUSA - 23/1136
# scraping PRI - 24/1136
# scraping GNMK - 25/1136
# scraping JKS - 26/1136
# scraping EXPR - 27/1136
# scraping RRTS - 28/1136
# scraping TNAV - 29/1136
# scraping PLOW - 30/1136
# scraping TSLA - 31/1136
# scraping FN - 32/1136
# scraping OAS - 33/1136
# scraping BORN - 34/1136
# scraping GDOT - 35/1136
# scraping AMRC - 36/1136
# scraping WSR - 37/1136
# scraping ELMD - 38/1136
# scraping MMYT - 39/1136
# scraping RP - 40/1136
# scraping NXPI - 41/1136
# scraping AMRS - 42/1136
# scraping COR - 43/1136
# scraping SFUN - 44/1136
# scraping PACB - 45/1136
# scraping VRA - 46/1136
# scraping TOWR - 47/1136
# scraping EFC - 48/1136
# scraping DQ - 49/1136
# scraping STND - 50/1136
# scraping CCIH - 51/1136
# scraping KEYW - 52/1136
# scraping GLBS - 53/1136
# scraping ZGNX - 54/1136
# scraping GM - 55/1136
# scraping LPLA - 56/1136
# scraping BAH - 57/1136
# scraping BITA - 58/1136
# scraping IPHI - 59/1136
# scraping GNOM - 60/1136
# scraping HHC - 61/1136
# scraping NOAH - 62/1136
# scraping PRMW - 63/1136
# scraping CMRE - 64/1136
# scraping OSN - 65/1136
# scraping WD - 66/1136
# scraping RNET - 67/1136
# scraping FLT - 68/1136
# scraping GCAP - 69/1136
# scraping LEDS - 70/1136
# scraping TRGP - 71/1136
# scraping AGRO - 72/1136
# scraping BKU - 73/1136
# scraping INXN - 74/1136
# scraping NLSN - 75/1136
# scraping TBET - 76/1136
# scraping AAT - 77/1136
# scraping ACRX - 78/1136
# scraping KMI - 79/1136
# scraping FLDM - 80/1136
# scraping INN - 81/1136
# scraping GEVO - 82/1136
# scraping BGMD - 83/1136
# scraping PCRX - 84/1136
# scraping NPTN - 85/1136
# scraping APO - 86/1136
# scraping SREV - 87/1136
# scraping CSOD - 88/1136
# scraping MX - 89/1136
# scraping HCA - 90/1136
# scraping VNET - 91/1136
# scraping AL - 92/1136
# scraping ELLI - 93/1136
# scraping SQNS - 94/1136
# scraping ARCO - 95/1136
# scraping GMLP - 96/1136
# scraping UAN - 97/1136
# scraping SDT - 98/1136
# scraping GNC - 99/1136
# scraping APTS - 100/1136
# scraping SAVE - 101/1136
# scraping YNDX - 102/1136
# scraping FENG - 103/1136
# scraping NGL - 104/1136
# scraping KOS - 105/1136
# scraping VOC - 106/1136
# scraping THR - 107/1136
# scraping RENN - 108/1136
# scraping WIFI - 109/1136
# scraping MITT - 110/1136
# scraping CHEF - 111/1136
# scraping WAIR - 112/1136
# scraping HZNP - 113/1136
# scraping AMID - 114/1136
# scraping DNKN - 115/1136
# scraping FRAN - 116/1136
# scraping SXC - 117/1136
# scraping Z - 118/1136
# scraping CARB - 119/1136
# scraping BLMT - 120/1136
# scraping UBNT - 121/1136
# scraping IMI - 122/1136
# scraping MN - 123/1136
# scraping ANGI - 124/1136
# scraping CLVS - 125/1136
# scraping CHKR - 126/1136
# scraping NLNK - 127/1136
# scraping PACD - 128/1136
# scraping GRPN - 129/1136
# scraping ZNGA - 130/1136
# scraping BCEI - 131/1136
# scraping LPI - 132/1136
# scraping MCEP - 133/1136
# scraping VSTM - 134/1136
# scraping GWRE - 135/1136
# scraping REGI - 136/1136
# scraping PRLB - 137/1136
# scraping BCOV - 138/1136
# scraping HMST - 139/1136
# scraping SYNC - 140/1136
# scraping CCXI - 141/1136
# scraping CPAC - 142/1136
# scraping CZR - 143/1136
# scraping EPAM - 144/1136
# scraping MTDR - 145/1136
# scraping SLCA - 146/1136
# scraping ENPH - 147/1136
# scraping GLOG - 148/1136
# scraping MACK - 149/1136
# scraping RXN - 150/1136
# scraping RM - 151/1136
# scraping VCRA - 152/1136
# scraping VIPS - 153/1136
# scraping CSTE - 154/1136
# scraping ET - 155/1136
# scraping ALSN - 156/1136
# scraping MTSI - 157/1136
# scraping YELP - 158/1136
# scraping ARCT - 159/1136
# scraping ACRE - 160/1136
# scraping CLIR - 161/1136
# scraping MPO - 162/1136
# scraping PFPT - 163/1136
# scraping SPLK - 164/1136
# scraping SDR - 165/1136
# scraping MRC - 166/1136
# scraping FET - 167/1136
# scraping RPAI - 168/1136
# scraping FB - 169/1136
# scraping WAGE - 170/1136
# scraping TLYS - 171/1136
# scraping ROYT - 172/1136
# scraping CG - 173/1136
# scraping SUPN - 174/1136
# scraping NOW - 175/1136
# scraping EQM - 176/1136
# scraping DFRG - 177/1136
# scraping NGVC - 178/1136
# scraping CHUY - 179/1136
# scraping PANW - 180/1136
# scraping FIVE - 181/1136
# scraping FSBW - 182/1136
# scraping HCLP - 183/1136
# scraping MANU - 184/1136
# scraping PFMT - 185/1136
# scraping BLMN - 186/1136
# scraping GMED - 187/1136
# scraping QLYS - 188/1136
# scraping SMLP - 189/1136
# scraping NBHC - 190/1136
# scraping SRC - 191/1136
# scraping MPLX - 192/1136
# scraping SDLP - 193/1136
# scraping WDAY - 194/1136
# scraping FANG - 195/1136
# scraping ICPT - 196/1136
# scraping SSTK - 197/1136
# scraping RLGY - 198/1136
# scraping AMBA - 199/1136
# scraping ANFI - 200/1136
# scraping BERY - 201/1136
# scraping RGLS - 202/1136
# scraping LXFR - 203/1136
# scraping YY - 204/1136
# scraping WHLR - 205/1136
# scraping ATOS - 206/1136
# scraping DKL - 207/1136
# scraping RH - 208/1136
# scraping PBF - 209/1136
# scraping TPH - 210/1136
# scraping LAND - 211/1136
# scraping STML - 212/1136
# scraping BFAM - 213/1136
# scraping NCLH - 214/1136
# scraping CONE - 215/1136
# scraping SXCP - 216/1136
# scraping USAC - 217/1136
# scraping AFH - 218/1136
# scraping CNOB - 219/1136
# scraping HIIQ - 220/1136
# scraping XONE - 221/1136
# scraping BCC - 222/1136
# scraping ZTS - 223/1136
# scraping MRIN - 224/1136
# scraping ENTA - 225/1136
# scraping MODN - 226/1136
# scraping TTPH - 227/1136
# scraping APAM - 228/1136
# scraping IPDN - 229/1136
# scraping SEAS - 230/1136
# scraping I - 231/1136
# scraping HASI - 232/1136
# scraping EVTC - 233/1136
# scraping CMRX - 234/1136
# scraping KNOP - 235/1136
# scraping TMHC - 236/1136
# scraping IBTX - 237/1136
# scraping EPZM - 238/1136
# scraping KMDA - 239/1136
# scraping ECOM - 240/1136
# scraping BRSS - 241/1136
# scraping CSTM - 242/1136
# scraping PTLA - 243/1136
# scraping DATA - 244/1136
# scraping WLH - 245/1136
# scraping EMES - 246/1136
# scraping TSC - 247/1136
# scraping AHH - 248/1136
# scraping QIWI - 249/1136
# scraping VOYA - 250/1136
# scraping INSY - 251/1136
# scraping GWPH - 252/1136
# scraping EARN - 253/1136
# scraping NDLS - 254/1136
# scraping SAMG - 255/1136
# scraping PETX - 256/1136
# scraping CDW - 257/1136
# scraping HDS - 258/1136
# scraping ESPR - 259/1136
# scraping NSTG - 260/1136
# scraping LXFT - 261/1136
# scraping GOGO - 262/1136
# scraping PTCT - 263/1136
# scraping THST - 264/1136
# scraping BLUE - 265/1136
# scraping COTY - 266/1136
# scraping BEP - 267/1136
# scraping LITB - 268/1136
# scraping ONTX - 269/1136
# scraping CNAT - 270/1136
# scraping AGIO - 271/1136
# scraping JONE - 272/1136
# scraping GRAM - 273/1136
# scraping HTBX - 274/1136
# scraping PSXP - 275/1136
# scraping REXR - 276/1136
# scraping DOC - 277/1136
# scraping OMED - 278/1136
# scraping SPHS - 279/1136
# scraping IRT - 280/1136
# scraping MIXT - 281/1136
# scraping FI - 282/1136
# scraping XON - 283/1136
# scraping FOXF - 284/1136
# scraping CTRL - 285/1136
# scraping MBII - 286/1136
# scraping SFM - 287/1136
# scraping AMH - 288/1136
# scraping ASC - 289/1136
# scraping PEGI - 290/1136
# scraping RNG - 291/1136
# scraping PINC - 292/1136
# scraping AAOI - 293/1136
# scraping EVOK - 294/1136
# scraping OPHT - 295/1136
# scraping FEYE - 296/1136
# scraping BIND - 297/1136
# scraping XLRN - 298/1136
# scraping FPRX - 299/1136
# scraping BNFT - 300/1136
# scraping VLRS - 301/1136
# scraping ESNT - 302/1136
# scraping MMI - 303/1136
# scraping WUBA - 304/1136
# scraping VCYT - 305/1136
# scraping BRX - 306/1136
# scraping CRTO - 307/1136
# scraping COMM - 308/1136
# scraping SRLP - 309/1136
# scraping EIGI - 310/1136
# scraping AERI - 311/1136
# scraping VJET - 312/1136
# scraping VEEV - 313/1136
# scraping PAGP - 314/1136
# scraping MGNX - 315/1136
# scraping AR - 316/1136
# scraping QTS - 317/1136
# scraping PBPB - 318/1136
# scraping CHMI - 319/1136
# scraping BURL - 320/1136
# scraping ESRT - 321/1136
# scraping RMAX - 322/1136
# scraping FATE - 323/1136
# scraping IPWR - 324/1136
# scraping OXFD - 325/1136
# scraping VNCE - 326/1136
# scraping WBAI - 327/1136
# scraping NVGS - 328/1136
# scraping EVGN - 329/1136
# scraping TNDM - 330/1136
# scraping HMHC - 331/1136
# scraping EROS - 332/1136
# scraping DLNG - 333/1136
# scraping CHGG - 334/1136
# scraping STAY - 335/1136
# scraping NMIH - 336/1136
# scraping LGIH - 337/1136
# scraping TWTR - 338/1136
# scraping WIX - 339/1136
# scraping KPTI - 340/1136
# scraping AVH - 341/1136
# scraping BCRH - 342/1136
# scraping TCS - 343/1136
# scraping AMC - 344/1136
# scraping HLT - 345/1136
# scraping KIN - 346/1136
# scraping SALT - 347/1136
# scraping TLOG - 348/1136
# scraping CTT - 349/1136
# scraping ARMK - 350/1136
# scraping ATHM - 351/1136
# scraping XNCR - 352/1136
# scraping CARA - 353/1136
# scraping NWHM - 354/1136
# scraping RARE - 355/1136
# scraping MBUU - 356/1136
# scraping TRVN - 357/1136
# scraping DRNA - 358/1136
# scraping CRCM - 359/1136
# scraping AKER - 360/1136
# scraping SC - 361/1136
# scraping EPE - 362/1136
# scraping CELP - 363/1136
# scraping GLYC - 364/1136
# scraping RTRX - 365/1136
# scraping VRNS - 366/1136
# scraping SMLR - 367/1136
# scraping INGN - 368/1136
# scraping IBP - 369/1136
# scraping CNCE - 370/1136
# scraping EGRX - 371/1136
# scraping FLXN - 372/1136
# scraping GPRK - 373/1136
# scraping LADR - 374/1136
# scraping RVNC - 375/1136
# scraping QURE - 376/1136
# scraping GNCA - 377/1136
# scraping CBPX - 378/1136
# scraping BIOC - 379/1136
# scraping BRG - 380/1136
# scraping HIVE - 381/1136
# scraping TWOU - 382/1136
# scraping WATT - 383/1136
# scraping TNET - 384/1136
# scraping AGTC - 385/1136
# scraping AMBR - 386/1136
# scraping ATEN - 387/1136
# scraping QTWO - 388/1136
# scraping AKBA - 389/1136
# scraping MDWD - 390/1136
# scraping PCTY - 391/1136
# scraping CSLT - 392/1136
# scraping GLMD - 393/1136
# scraping AKAO - 394/1136
# scraping AQXP - 395/1136
# scraping REPH - 396/1136
# scraping SABR - 397/1136
# scraping SPWH - 398/1136
# scraping LEJU - 399/1136
# scraping MC - 400/1136
# scraping PAYC - 401/1136
# scraping CIO - 402/1136
# scraping WB - 403/1136
# scraping PAHC - 404/1136
# scraping FPI - 405/1136
# scraping ENBL - 406/1136
# scraping ADMS - 407/1136
# scraping ALLY - 408/1136
# scraping GRUB - 409/1136
# scraping FIVN - 410/1136
# scraping TEDU - 411/1136
# scraping RUBI - 412/1136
# scraping PIH - 413/1136
# scraping RESN - 414/1136
# scraping PE - 415/1136
# scraping AGRX - 416/1136
# scraping HRTG - 417/1136
# scraping SDPI - 418/1136
# scraping JD - 419/1136
# scraping TGEN - 420/1136
# scraping TRUE - 421/1136
# scraping JMEI - 422/1136
# scraping BWFG - 423/1136
# scraping ZEN - 424/1136
# scraping SFBS - 425/1136
# scraping TOUR - 426/1136
# scraping PBFX - 427/1136
# scraping CMCM - 428/1136
# scraping LPG - 429/1136
# scraping ALDR - 430/1136
# scraping GLOP - 431/1136
# scraping SCYX - 432/1136
# scraping FRSH - 433/1136
# scraping ALDX - 434/1136
# scraping ARES - 435/1136
# scraping MIK - 436/1136
# scraping NEP - 437/1136
# scraping SERV - 438/1136
# scraping GPRO - 439/1136
# scraping AMPH - 440/1136
# scraping MTLS - 441/1136
# scraping XNET - 442/1136
# scraping ARDX - 443/1136
# scraping ZFGN - 444/1136
# scraping VNOM - 445/1136
# scraping FELP - 446/1136
# scraping CCS - 447/1136
# scraping ASPN - 448/1136
# scraping MOBL - 449/1136
# scraping TSE - 450/1136
# scraping NAO - 451/1136
# scraping RDUS - 452/1136
# scraping ANET - 453/1136
# scraping CTLT - 454/1136
# scraping HQY - 455/1136
# scraping MRNS - 456/1136
# scraping SYF - 457/1136
# scraping WLKP - 458/1136
# scraping SPKE - 459/1136
# scraping LOCO - 460/1136
# scraping OCUL - 461/1136
# scraping OEC - 462/1136
# scraping WMS - 463/1136
# scraping XENT - 464/1136
# scraping TSQ - 465/1136
# scraping PFNX - 466/1136
# scraping IMDZ - 467/1136
# scraping MTBC - 468/1136
# scraping GLOB - 469/1136
# scraping SAGE - 470/1136
# scraping TERP - 471/1136
# scraping TRUP - 472/1136
# scraping CDNA - 473/1136
# scraping IRMD - 474/1136
# scraping ISTR - 475/1136
# scraping NERV - 476/1136
# scraping OTIC - 477/1136
# scraping RYI - 478/1136
# scraping ICD - 479/1136
# scraping HMLP - 480/1136
# scraping TTOO - 481/1136
# scraping EARS - 482/1136
# scraping GWGH - 483/1136
# scraping TVPT - 484/1136
# scraping MDLY - 485/1136
# scraping SFS - 486/1136
# scraping ICL - 487/1136
# scraping CYBR - 488/1136
# scraping CFG - 489/1136
# scraping AVAL - 490/1136
# scraping BABA - 491/1136
# scraping FOMX - 492/1136
# scraping PRQR - 493/1136
# scraping RWLK - 494/1136
# scraping AFMD - 495/1136
# scraping BOOT - 496/1136
# scraping FSAM - 497/1136
# scraping SHLX - 498/1136
# scraping SIEN - 499/1136
# scraping DBVT - 500/1136
# scraping PRTO - 501/1136
# scraping ZAYO - 502/1136
# scraping ATRA - 503/1136
# scraping FWP - 504/1136
# scraping GWB - 505/1136
# scraping PLAY - 506/1136
# scraping DPLO - 507/1136
# scraping HUBS - 508/1136
# scraping USDP - 509/1136
# scraping VBTX - 510/1136
# scraping DERM - 511/1136
# scraping ATTO - 512/1136
# scraping AAC - 513/1136
# scraping CALA - 514/1136
# scraping W - 515/1136
# scraping VSLR - 516/1136
# scraping VBLT - 517/1136
# scraping SKIS - 518/1136
# scraping HABT - 519/1136
# scraping EYES - 520/1136
# scraping PGRE - 521/1136
# scraping STOR - 522/1136
# scraping EHIC - 523/1136
# scraping FGEN - 524/1136
# scraping LMRK - 525/1136
# scraping PRAH - 526/1136
# scraping SKYS - 527/1136
# scraping AXTA - 528/1136
# scraping JYNT - 529/1136
# scraping FRPT - 530/1136
# scraping TBK - 531/1136
# scraping UPLD - 532/1136
# scraping CHRS - 533/1136
# scraping NVRO - 534/1136
# scraping AM - 535/1136
# scraping XENE - 536/1136
# scraping BLCM - 537/1136
# scraping ONDK - 538/1136
# scraping WK - 539/1136
# scraping NEWR - 540/1136
# scraping FCAU - 541/1136
# scraping JRVR - 542/1136
# scraping LC - 543/1136
# scraping MOMO - 544/1136
# scraping HSGX - 545/1136
# scraping AVGR - 546/1136
# scraping HIFR - 547/1136
# scraping ONCE - 548/1136
# scraping SHAK - 549/1136
# scraping TCON - 550/1136
# scraping LENS - 551/1136
# scraping FLKS - 552/1136
# scraping ASND - 553/1136
# scraping ZSAN - 554/1136
# scraping EURN - 555/1136
# scraping BOX - 556/1136
# scraping ICBK - 557/1136
# scraping AJX - 558/1136
# scraping BLPH - 559/1136
# scraping NVTA - 560/1136
# scraping INOV - 561/1136
# scraping DEA - 562/1136
# scraping JCAP - 563/1136
# scraping FSB - 564/1136
# scraping SEDG - 565/1136
# scraping CLLS - 566/1136
# scraping TANH - 567/1136
# scraping NCOM - 568/1136
# scraping SUM - 569/1136
# scraping SMMT - 570/1136
# scraping BPMC - 571/1136
# scraping EVA - 572/1136
# scraping VKTX - 573/1136
# scraping NSA - 574/1136
# scraping PRTY - 575/1136
# scraping VIRT - 576/1136
# scraping KMPH - 577/1136
# scraping ETSY - 578/1136
# scraping XBIT - 579/1136
# scraping CDTX - 580/1136
# scraping ADRO - 581/1136
# scraping KRNT - 582/1136
# scraping GDDY - 583/1136
# scraping BZUN - 584/1136
# scraping CHCT - 585/1136
# scraping SHOP - 586/1136
# scraping FTAI - 587/1136
# scraping RKDA - 588/1136
# scraping GLPG - 589/1136
# scraping JAGX - 590/1136
# scraping BVXV - 591/1136
# scraping COLL - 592/1136
# scraping LIFE - 593/1136
# scraping HTGM - 594/1136
# scraping ADAP - 595/1136
# scraping OPGN - 596/1136
# scraping BSM - 597/1136
# scraping ALRM - 598/1136
# scraping APPF - 599/1136
# scraping GPP - 600/1136
# scraping MCRB - 601/1136
# scraping TRU - 602/1136
# scraping MCRN - 603/1136
# scraping LNTH - 604/1136
# scraping GKOS - 605/1136
# scraping CATB - 606/1136
# scraping RTTR - 607/1136
# scraping CYAD - 608/1136
# scraping FIT - 609/1136
# scraping UNVR - 610/1136
# scraping WING - 611/1136
# scraping PUB - 612/1136
# scraping EVH - 613/1136
# scraping DTEA - 614/1136
# scraping AQMS - 615/1136
# scraping XELB - 616/1136
# scraping VTVT - 617/1136
# scraping NK - 618/1136
# scraping NEOS - 619/1136
# scraping LOB - 620/1136
# scraping MCFT - 621/1136
# scraping OOMA - 622/1136
# scraping RPD - 623/1136
# scraping OLLI - 624/1136
# scraping JP - 625/1136
# scraping CHMA - 626/1136
# scraping HLG - 627/1136
# scraping NTRA - 628/1136
# scraping CFMS - 629/1136
# scraping TDOC - 630/1136
# scraping UFAB - 631/1136
# scraping BNTC - 632/1136
# scraping HLI - 633/1136
# scraping GBT - 634/1136
# scraping AIMT - 635/1136
# scraping PLNT - 636/1136
# scraping RUN - 637/1136
# scraping ZYNE - 638/1136
# scraping NTEC - 639/1136
# scraping NBRV - 640/1136
# scraping PEN - 641/1136
# scraping RGNX - 642/1136
# scraping MYOK - 643/1136
# scraping IOTS - 644/1136
# scraping OASM - 645/1136
# scraping RACE - 646/1136
# scraping SBBP - 647/1136
# scraping FDC - 648/1136
# scraping PMTS - 649/1136
# scraping CTMX - 650/1136
# scraping ABTX - 651/1136
# scraping ACRS - 652/1136
# scraping PSTG - 653/1136
# scraping NVCR - 654/1136
# scraping PFGC - 655/1136
# scraping EDGE - 656/1136
# scraping SGRY - 657/1136
# scraping DLTH - 658/1136
# scraping KTOV - 659/1136
# scraping AXSM - 660/1136
# scraping MIME - 661/1136
# scraping MTCH - 662/1136
# scraping SQ - 663/1136
# scraping MESO - 664/1136
# scraping INST - 665/1136
# scraping XCOM - 666/1136
# scraping VYGR - 667/1136
# scraping WVE - 668/1136
# scraping EQBK - 669/1136
# scraping KURA - 670/1136
# scraping FORK - 671/1136
# scraping CCRC - 672/1136
# scraping YRD - 673/1136
# scraping TEAM - 674/1136
# scraping PTI - 675/1136
# scraping BGNE - 676/1136
# scraping EDIT - 677/1136
# scraping CRVS - 678/1136
# scraping SENS - 679/1136
# scraping HCM - 680/1136
# scraping SNDX - 681/1136
# scraping GWRS - 682/1136
# scraping RRR - 683/1136
# scraping YIN - 684/1136
# scraping SCWX - 685/1136
# scraping ARA - 686/1136
# scraping MGP - 687/1136
# scraping AGLE - 688/1136
# scraping GMS - 689/1136
# scraping RETA - 690/1136
# scraping USFD - 691/1136
# scraping MSBI - 692/1136
# scraping MRUS - 693/1136
# scraping SUPV - 694/1136
# scraping PLSE - 695/1136
# scraping ACIA - 696/1136
# scraping SITE - 697/1136
# scraping TPB - 698/1136
# scraping SBPH - 699/1136
# scraping NTLA - 700/1136
# scraping SYRS - 701/1136
# scraping GMRE - 702/1136
# scraping TWLO - 703/1136
# scraping SELB - 704/1136
# scraping VIVE - 705/1136
# scraping COE - 706/1136
# scraping ATKR - 707/1136
# scraping CLSD - 708/1136
# scraping MBRX - 709/1136
# scraping NH - 710/1136
# scraping APOP - 711/1136
# scraping TLND - 712/1136
# scraping TCMD - 713/1136
# scraping KNSL - 714/1136
# scraping KDMN - 715/1136
# scraping TPIC - 716/1136
# scraping PI - 717/1136
# scraping BOLD - 718/1136
# scraping LN - 719/1136
# scraping AIRG - 720/1136
# scraping MEDP - 721/1136
# scraping PTGX - 722/1136
# scraping GEMP - 723/1136
# scraping HOME - 724/1136
# scraping FHB - 725/1136
# scraping NTNX - 726/1136
# scraping TRHC - 727/1136
# scraping MRT - 728/1136
# scraping FLGT - 729/1136
# scraping TYHT - 730/1136
# scraping VVV - 731/1136
# scraping GSUM - 732/1136
# scraping ACIU - 733/1136
# scraping CSTR - 734/1136
# scraping ELF - 735/1136
# scraping NOVN - 736/1136
# scraping TTD - 737/1136
# scraping EVBG - 738/1136
# scraping FBK - 739/1136
# scraping NTB - 740/1136
# scraping NBLX - 741/1136
# scraping BL - 742/1136
# scraping GOLF - 743/1136
# scraping QTNA - 744/1136
# scraping ZTO - 745/1136
# scraping MYOV - 746/1136
# scraping RARX - 747/1136
# scraping FRTA - 748/1136
# scraping IRTC - 749/1136
# scraping CRSP - 750/1136
# scraping TUSK - 751/1136
# scraping XOG - 752/1136
# scraping AZRE - 753/1136
# scraping AZRX - 754/1136
# scraping CWH - 755/1136
# scraping MRAM - 756/1136
# scraping ADSW - 757/1136
# scraping OBLN - 758/1136
# scraping COUP - 759/1136
# scraping WAAS - 760/1136
# scraping MTFB - 761/1136
# scraping SND - 762/1136
# scraping GDS - 763/1136
# scraping HEBT - 764/1136
# scraping TRVG - 765/1136
# scraping ICHR - 766/1136
# scraping SNES - 767/1136
# scraping POLA - 768/1136
# scraping IIPR - 769/1136
# scraping JAG - 770/1136
# scraping JELD - 771/1136
# scraping JNCE - 772/1136
# scraping REVG - 773/1136
# scraping OBSV - 774/1136
# scraping ANAB - 775/1136
# scraping FRAC - 776/1136
# scraping CLPR - 777/1136
# scraping FBM - 778/1136
# scraping SACH - 779/1136
# scraping METC - 780/1136
# scraping KRP - 781/1136
# scraping LAUR - 782/1136
# scraping INVH - 783/1136
# scraping AYX - 784/1136
# scraping VLRX - 785/1136
# scraping TRPX - 786/1136
# scraping PUMP - 787/1136
# scraping ARD - 788/1136
# scraping PSDO - 789/1136
# scraping JILL - 790/1136
# scraping BYSI - 791/1136
# scraping SNAP - 792/1136
# scraping HLNE - 793/1136
# scraping CLDR - 794/1136
# scraping CVNA - 795/1136
# scraping EEX - 796/1136
# scraping NCSM - 797/1136
# scraping XRF - 798/1136
# scraping ZYME - 799/1136
# scraping VRNA - 800/1136
# scraping FND - 801/1136
# scraping CATS - 802/1136
# scraping WTTR - 803/1136
# scraping TOCA - 804/1136
# scraping CADE - 805/1136
# scraping HCC - 806/1136
# scraping YEXT - 807/1136
# scraping NETS - 808/1136
# scraping OKTA - 809/1136
# scraping SNDR - 810/1136
# scraping ELVT - 811/1136
# scraping HESM - 812/1136
# scraping APPN - 813/1136
# scraping WOW - 814/1136
# scraping SGH - 815/1136
# scraping ARGX - 816/1136
# scraping BEDU - 817/1136
# scraping GTHX - 818/1136
# scraping SOI - 819/1136
# scraping ASV - 820/1136
# scraping GDI - 821/1136
# scraping VERI - 822/1136
# scraping FPH - 823/1136
# scraping GNTY - 824/1136
# scraping OVID - 825/1136
# scraping URGN - 826/1136
# scraping AMGP - 827/1136
# scraping BHVN - 828/1136
# scraping BY - 829/1136
# scraping ALRN - 830/1136
# scraping APRN - 831/1136
# scraping DOVA - 832/1136
# scraping MRSN - 833/1136
# scraping ESQ - 834/1136
# scraping ATXI - 835/1136
# scraping GPMT - 836/1136
# scraping SAFE - 837/1136
# scraping SGBX - 838/1136
# scraping ATUS - 839/1136
# scraping BOMN - 840/1136
# scraping ADOM - 841/1136
# scraping ATNX - 842/1136
# scraping PLYM - 843/1136
# scraping IMRN - 844/1136
# scraping SSTI - 845/1136
# scraping NEWA - 846/1136
# scraping RDFN - 847/1136
# scraping SNNA - 848/1136
# scraping RBB - 849/1136
# scraping PETQ - 850/1136
# scraping KALA - 851/1136
# scraping CLXT - 852/1136
# scraping AKCA - 853/1136
# scraping CODX - 854/1136
# scraping CSSE - 855/1136
# scraping RNGR - 856/1136
# scraping YOGA - 857/1136
# scraping ZEAL - 858/1136
# scraping CIFS - 859/1136
# scraping VNTR - 860/1136
# scraping CMTA - 861/1136
# scraping PQG - 862/1136
# scraping ROKU - 863/1136
# scraping DCPH - 864/1136
# scraping NCNA - 865/1136
# scraping NITE - 866/1136
# scraping RYB - 867/1136
# scraping SECO - 868/1136
# scraping OMP - 869/1136
# scraping PETZ - 870/1136
# scraping DESP - 871/1136
# scraping CELC - 872/1136
# scraping KRYS - 873/1136
# scraping ZLAB - 874/1136
# scraping TRMT - 875/1136
# scraping ZKIN - 876/1136
# scraping FSCT - 877/1136
# scraping MBIN - 878/1136
# scraping NEXA - 879/1136
# scraping EYE - 880/1136
# scraping BPMP - 881/1136
# scraping FAT - 882/1136
# scraping LYL - 883/1136
# scraping REDU - 884/1136
# scraping RMBL - 885/1136
# scraping SE - 886/1136
# scraping MDB - 887/1136
# scraping QD - 888/1136
# scraping OPTN - 889/1136
# scraping KIDS - 890/1136
# scraping HAIR - 891/1136
# scraping CARG - 892/1136
# scraping SWCH - 893/1136
# scraping RYTM - 894/1136
# scraping BOXL - 895/1136
# scraping RETO - 896/1136
# scraping BXG - 897/1136
# scraping AMRH - 898/1136
# scraping SAIL - 899/1136
# scraping SBT - 900/1136
# scraping SCPH - 901/1136
# scraping SFIX - 902/1136
# scraping JT - 903/1136
# scraping ASNS - 904/1136
# scraping PPDF - 905/1136
# scraping BAND - 906/1136
# scraping ERYP - 907/1136
# scraping APLS - 908/1136
# scraping SOGO - 909/1136
# scraping MCB - 910/1136
# scraping FEDU - 911/1136
# scraping IFRX - 912/1136
# scraping CBTX - 913/1136
# scraping HX - 914/1136
# scraping AQ - 915/1136
# scraping ACMR - 916/1136
# scraping SPRO - 917/1136
# scraping ALNA - 918/1136
# scraping AQUA - 919/1136
# scraping FNKO - 920/1136
# scraping ALTR - 921/1136
# scraping LOMA - 922/1136
# scraping ICLK - 923/1136
# scraping LX - 924/1136
# scraping DOGZ - 925/1136
# scraping CASA - 926/1136
# scraping NMRK - 927/1136
# scraping DNLI - 928/1136
# scraping LBC - 929/1136
# scraping CURO - 930/1136
# scraping ODT - 931/1136
# scraping QTRX - 932/1136
# scraping AGS - 933/1136
# scraping SLDB - 934/1136
# scraping TORC - 935/1136
# scraping EYEN - 936/1136
# scraping GTES - 937/1136
# scraping MNLO - 938/1136
# scraping PAGS - 939/1136
# scraping NINE - 940/1136
# scraping ADT - 941/1136
# scraping COLD - 942/1136
# scraping ILPT - 943/1136
# scraping LBRT - 944/1136
# scraping CUE - 945/1136
# scraping FAMI - 946/1136
# scraping BFRA - 947/1136
# scraping MOTS - 948/1136
# scraping CDLX - 949/1136
# scraping QES - 950/1136
# scraping VCTR - 951/1136
# scraping WHD - 952/1136
# scraping EOLS - 953/1136
# scraping HMI - 954/1136
# scraping SSLJ - 955/1136
# scraping FTSI - 956/1136
# scraping CEPU - 957/1136
# scraping CAAP - 958/1136
# scraping HUD - 959/1136
# scraping IPIC - 960/1136
# scraping OSS - 961/1136
# scraping VICI - 962/1136
# scraping SLGL - 963/1136
# scraping GNPX - 964/1136
# scraping IQ - 965/1136
# scraping UMRX - 966/1136
# scraping ONE - 967/1136
# scraping OPBK - 968/1136
# scraping BILI - 969/1136
# scraping FIXX - 970/1136
# scraping GHG - 971/1136
# scraping DBX - 972/1136
# scraping STG - 973/1136
# scraping DNJR - 974/1136
# scraping AIHS - 975/1136
# scraping ZS - 976/1136
# scraping RCUS - 977/1136
# scraping BWB - 978/1136
# scraping BTAI - 979/1136
# scraping DOCU - 980/1136
# scraping GSHD - 981/1136
# scraping SMAR - 982/1136
# scraping LASR - 983/1136
# scraping CDAY - 984/1136
# scraping LEVL - 985/1136
# scraping PVTL - 986/1136
# scraping SURF - 987/1136
# scraping MOR - 988/1136
# scraping EAF - 989/1136
# scraping AGMH - 990/1136
# scraping ZUO - 991/1136
# scraping SPOT - 992/1136
# scraping HJLI - 993/1136
# scraping ITRM - 994/1136
# scraping KNSA - 995/1136
# scraping SRRK - 996/1136
# scraping GSKY - 997/1136
# scraping CLPS - 998/1136
# scraping EVOP - 999/1136
# scraping PS - 1000/1136
# scraping HUYA - 1001/1136
# scraping EQH - 1002/1136
# scraping EVLO - 1003/1136
# scraping OBNK - 1004/1136
# scraping ROAD - 1005/1136
# scraping STXB - 1006/1136
# scraping ASLN - 1007/1136
# scraping BCML - 1008/1136
# scraping CBLK - 1009/1136
# scraping INSP - 1010/1136
# scraping UBX - 1011/1136
# scraping PRT - 1012/1136
# scraping DOMO - 1013/1136
# scraping BJ - 1014/1136
# scraping BV - 1015/1136
# scraping ENTX - 1016/1136
# scraping EVER - 1017/1136
# scraping FTSV - 1018/1136
# scraping STIM - 1019/1136
# scraping TBIO - 1020/1136
# scraping TCDA - 1021/1136
# scraping UXIN - 1022/1136
# scraping NTGN - 1023/1136
# scraping LOVE - 1024/1136
# scraping HYRE - 1025/1136
# scraping ECOR - 1026/1136
# scraping AUTL - 1027/1136
# scraping APTX - 1028/1136
# scraping IIIV - 1029/1136
# scraping KZR - 1030/1136
# scraping MGTA - 1031/1136
# scraping AVRO - 1032/1136
# scraping XERS - 1033/1136
# scraping EIDX - 1034/1136
# scraping VRCA - 1035/1136
# scraping NEW - 1036/1136
# scraping AVLR - 1037/1136
# scraping CHRA - 1038/1136
# scraping USX - 1039/1136
# scraping MGTX - 1040/1136
# scraping AMBO - 1041/1136
# scraping ADIL - 1042/1136
# scraping DAVA - 1043/1136
# scraping OPRA - 1044/1136
# scraping WISA - 1045/1136
# scraping JG - 1046/1136
# scraping LQDA - 1047/1136
# scraping TENB - 1048/1136
# scraping PDD - 1049/1136
# scraping FOCS - 1050/1136
# scraping BRY - 1051/1136
# scraping CANG - 1052/1136
# scraping AQST - 1053/1136
# scraping BE - 1054/1136
# scraping PRVB - 1055/1136
# scraping REPL - 1056/1136
# scraping ESTA - 1057/1136
# scraping CNST - 1058/1136
# scraping TLRY - 1059/1136
# scraping MYFW - 1060/1136
# scraping ALLK - 1061/1136
# scraping CRNX - 1062/1136
# scraping CCB - 1063/1136
# scraping RUBY - 1064/1136
# scraping SFET - 1065/1136
# scraping ARDS - 1066/1136
# scraping MESA - 1067/1136
# scraping VCNX - 1068/1136
# scraping PCB - 1069/1136
# scraping ARLO - 1070/1136
# scraping SONO - 1071/1136
# scraping CWK - 1072/1136
# scraping CTK - 1073/1136
# scraping GRTS - 1074/1136
# scraping LAIX - 1075/1136
# scraping RMED - 1076/1136
# scraping STRO - 1077/1136
# scraping ARVN - 1078/1136
# scraping UROV - 1079/1136
# scraping ARCE - 1080/1136
# scraping CBNK - 1081/1136
# scraping ETTX - 1082/1136
# scraping SVMK - 1083/1136
# scraping VIOT - 1084/1136
# scraping YMAB - 1085/1136
# scraping FTCH - 1086/1136
# scraping BSVN - 1087/1136
# scraping EB - 1088/1136
# scraping ELAN - 1089/1136
# scraping XYF - 1090/1136
# scraping PRNB - 1091/1136
# scraping QTT - 1092/1136
# scraping FVCB - 1093/1136
# scraping NIO - 1094/1136
# scraping YI - 1095/1136
# scraping AXNX - 1096/1136
# scraping ORTX - 1097/1136
# scraping TWST - 1098/1136
# scraping GMDA - 1099/1136
# scraping STNE - 1100/1136
# scraping PT - 1101/1136
# scraping YETI - 1102/1136
# scraping LOGC - 1103/1136
# scraping NIU - 1104/1136
# scraping SWI - 1105/1136
# scraping MSC - 1106/1136
# scraping OSMT - 1107/1136
# scraping PHAS - 1108/1136
# scraping SIBN - 1109/1136
# scraping PLAN - 1110/1136
# scraping EQ - 1111/1136
# scraping ALLO - 1112/1136
# scraping LTHM - 1113/1136
# scraping ESTC - 1114/1136
# scraping GH - 1115/1136
# scraping KOD - 1116/1136
# scraping UPWK - 1117/1136
# scraping MDRR - 1118/1136
# scraping TLC - 1119/1136
# scraping TLSA - 1120/1136
# scraping TC - 1121/1136
# scraping WEI - 1122/1136
# scraping VAPO - 1123/1136
# scraping ETON - 1124/1136
# scraping TBLTU - 1125/1136
# scraping CNF - 1126/1136
# scraping PHCF - 1127/1136
# scraping AMTB - 1128/1136
# scraping APM - 1129/1136
# scraping QFIN - 1130/1136
# scraping LEGH - 1131/1136
# scraping TME - 1132/1136
# scraping THOR - 1133/1136
# scraping DMAC - 1134/1136
# scraping MRNA - 1135/1136
# scraping MOGU - 1136/1136
# checking lengths sector: 1136, industry: 1136, employees2019: 1136, CEO pay: 1136, CEO_born: 1136

# %%
employees2019_clean = []
for emp in employees2019:
    if emp is not np.nan:
        if len(emp) > 0:
            emp = int(emp.replace(',', ''))
        else:
            emp = np.nan
    employees2019_clean.append(emp)

# %%
CEO_pay_clean = []
for i, cp in enumerate(CEO_pay):
    if cp == cp:
        if isinstance(cp, float):
            print(i, cp)
            cp_clean = cp*1000
        elif 'M' in cp:
            print(i, cp)
            cp_clean = float(cp.replace("M", ""))*1000000
        elif 'k' in cp:
            print(i, cp)
            cp_clean = float(cp.replace("k", ""))*1000        
        CEO_pay_clean.append(cp_clean)
    elif cp != cp:
        print(i, 'this one', cp)
        CEO_pay_clean.append(cp)
# Out:
# 0 this one nan
# 1 2.32M
# 2 1.65M
# 3 816.15k
# 4 799.5k
# 5 1.91M
# 6 this one nan
# 7 10.88M
# 8 this one nan
# 9 this one nan
# 10 586.84k
# 11 1.71M
# 12 500k
# 13 554.71k
# 14 770.17k
# 15 1.57M
# 16 715.3k
# 17 1.34M
# 18 1.15M
# 19 501.12k
# 20 1.39M
# 21 2.39M
# 22 3.17M
# 23 2.39M
# 24 1M
# 25 this one nan
# 26 1.2M
# 27 839.92k
# 28 821.3k
# 29 854.23k
# 30 this one nan
# 31 700.01k
# 32 1.84M
# 33 this one nan
# 34 1.88M
# 35 1.17M
# 36 619.25k
# 37 418.35k
# 38 this one nan
# 39 1.38M
# 40 4.45M
# 41 1.8M
# 42 1.52M
# 43 this one nan
# 44 1.03M
# 45 1.4M
# 46 2.11M
# 47 this one nan
# 48 this one nan
# 49 this one nan
# 50 this one nan
# 51 978.89k
# 52 this one nan
# 53 869.7k
# 54 7.36M
# 55 3.26M
# 56 this one nan
# 57 this one nan
# 58 419.16k
# 59 this one nan
# 60 6.01M
# 61 this one nan
# 62 461.26k
# 63 this one nan
# 64 13.69k
# 65 2.25M
# 66 1.47M
# 67 2.53M
# 68 2.22M
# 69 303.75k
# 70 856.64k
# 71 this one nan
# 72 3.1M
# 73 this one nan
# 74 1.57M
# 75 this one nan
# 76 1.82M
# 77 941k
# 78 908.96k
# 79 1.05M
# 80 1.68M
# 81 790.22k
# 1112 1.77M
# 1113 706.49k
# 1114 818.4k
# 1115 727.54k
# 1116 808.44k
# 1117 this one nan
# 1118 this one nan
# 1119 this one nan
# 1120 this one nan
# 1121 this one nan
# 1122 521.04k
# 1123 493.02k
# 1124 444.05k
# 1125 this one nan
# 1126 this one nan
# 1127 2.63M
# 1128 this one nan
# 1129 this one nan
# 1130 50k
# 1131 this one nan
# 1132 606.48k
# 1133 492.4k
# 1134 2.67M
# 1135 this one nan

# %% [markdown]
# # Final DataFrame

# %%
df_ipo['sector'] = sector
df_ipo['industry'] = industry
df_ipo['employees2019'] = employees2019_clean
df_ipo['CEO_pay'] = CEO_pay_clean
df_ipo['CEO_born'] = CEO_born

# %%
df_ipo.head()
# Out:
#                                  Company Name Symbol                   Market  \
# AMCF  ANDATEE CHINA MARINE FUEL SERVICES CORP   AMCF                   NASDAQ
# CHSP                 CHESAPEAKE LODGING TRUST   CHSP  New York Stock Exchange
# GNRC                    GENERAC HOLDINGS INC.   GNRC  New York Stock Exchange
# QNST                          QUINSTREET, INC   QNST                   NASDAQ
# TRNO                      TERRENO REALTY CORP   TRNO  New York Stock Exchange
#
#       Price      Shares  Offer Amount Date Priced  employees  \
# AMCF    6.3   3134921.0    19750002.0  2010-01-26      128.0
# CHSP   20.0   7500000.0   150000000.0  2010-01-22        3.0
# GNRC   13.0  18750000.0   243750000.0  2010-02-11     1486.0
# QNST   15.0  10000000.0   150000000.0  2010-02-11      568.0
# TRNO   20.0   8750000.0   175000000.0  2010-02-10        6.0
#
#                                                 address US_state  ...  \
# AMCF  NO. 68 BINHAI RD DALIAN XIGANG DISTRICTDALIAN ...      NaN  ...
# CHSP  4300 WILSON BOULEVARDSUITE 625ARLINGTON, VA 22203       VA  ...
# GNRC            S45 W29290 HIGHWAY 59WAUKESHA, WI 53187       WI  ...
# QNST     950 TOWER LANE, 6TH FLOORFOSTER CITY, CA 94404       CA  ...
# TRNO   16 MAIDEN LANEFIFTH FLOORSAN FRANCISCO, CA 94108       CA  ...
#
#      inmonth_volume inweek_adjclose  inweek_open  inweek_spread  \
# AMCF       323300.0        5.830000     6.030000       0.280000
# CHSP        40500.0       11.927483    18.910000       0.139999
# GNRC       265400.0        8.612183    13.050000       0.290000
# QNST        27300.0       12.980000    13.500000       0.809999
# TRNO        64300.0       14.770803    18.809999       0.199999
#
#       inweek_volume       sector                        industry  \
# AMCF       106300.0       Energy  Oil & Gas Equipment & Services
# CHSP        75900.0  Real Estate            REIT - Hotel & Motel
# GNRC       110000.0  Industrials         Diversified Industrials
# QNST       504000.0   Technology  Internet Content & Information
# TRNO        91200.0  Real Estate               REIT - Industrial
#
#       employees2019    CEO_pay  CEO_born
# AMCF          189.0        NaN       NaN
# CHSP           13.0  2320000.0    1962.0
# GNRC         5046.0  1650000.0    1972.0
# QNST          506.0   816150.0    1960.0
# TRNO           23.0   799500.0    1961.0
#
# [5 rows x 30 columns]

# %%
df_ipo.shape
# Out:
# (1136, 30)

# %%
df_ipo.to_csv('ipo_stock_2010_2018.csv', index=False)
