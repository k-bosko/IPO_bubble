# %% [markdown]
# ### IPO price scraper - v2.0

# %% [markdown]
# In this script, I will scrape the stock info and company profile from Yahoo Finance for the IPO companies scraped in the previous step from NASDAQ site (see IPO_scraper.ipynb)
#
# This is the second version of the Yahoo Finance scraper. I changed the way the data is scraped - it now scrapes the trading prices only if the IPO date from Nasdaq data frame corresponds to date in Yahoo Finance. It turns out that by accessing the first value in Yahoo Finance (as in version 1.0) provides wrong results for some companies, because Yahoo Finance keep record for them longer than IPO priced date (why??).
#
# As a result, this scraper yielded more notscraped tickers than the scraper 1.0 <br>
# v 1.0 - From 1569 IPO companies listed on Nasdaq, 433 companies were not scraped on Yahoo Finance<br>
# v 2.0 - From 1533 IPO companies listed on Nasdaq, 703 companies were not scraped on Yahoo Finance<br>
#
# When running a month later, there was also more "misalignment between company name and its ticker" (no code changed), so instead of 1600 scraped from Nasdaq, after all the checks we got 1533 companies.<br>
#
# Example of nonscraped ticker is, e.g. 'MUSA'. The company was priced on NASDAQ on 2010-04-09. But the earliest date on Yahoo Finance is 2013-08-19.<br>
#
#
# <img src="assets/MUSA_example.png" alt="drawing" height="1500" width="800"/>
#
# The rest of the script is the same as in v1.0.

# %%
import re
from difflib import SequenceMatcher
import pandas_datareader.data as pdr #Yahoo Finance ticker
import pandas as pd
import numpy as np

from datetime import datetime

from bs4 import BeautifulSoup
import requests
from time import sleep

import dill

# %%
#run this cell if want to import dill from earlier session
#dill.load_session('dill/ipo_price_scraper.pkl')

# %%
df = pd.read_csv('data/ipo_clean_2010_2018.csv', parse_dates=['Date Priced', 'year'])
df.shape
# Out:
# (1600, 13)

# %%
df.dtypes
# Out:
# Company Name            object
# Symbol                  object
# Market                  object
# Price                  float64
# Shares                 float64
# Offer Amount           float64
# Date Priced     datetime64[ns]
# employees              float64
# address                 object
# US_state                object
# descriptions            object
# link_nasdaq             object
# year            datetime64[ns]
# dtype: object

# %% [markdown]
# ## Checking for duplicated tickers and company names:

# %%
print("number of duplicated companies in the dataset:", df['Company Name'].duplicated().sum())
# Out:
# number of duplicated companies in the dataset: 3

# %%
df[df['Company Name'].duplicated(keep=False)]
# Out:
#                       Company Name Symbol                   Market  Price  \
# 85    AMBOW EDUCATION HOLDING LTD.   AMBO  New York Stock Exchange  10.00
# 205           SANDRIDGE ENERGY INC    SDT  New York Stock Exchange  21.00
# 254           SANDRIDGE ENERGY INC    PER  New York Stock Exchange  18.00
# 341           SANDRIDGE ENERGY INC    SDR  New York Stock Exchange  21.00
# 1503  AMBOW EDUCATION HOLDING LTD.   AMBO                 NYSE MKT   4.25
#
#           Shares  Offer Amount Date Priced  employees  \
# 85    10677207.0   106772070.0  2010-08-05    10361.0
# 205   15000000.0   315000000.0  2011-04-07     2192.0
# 254   30000000.0   540000000.0  2011-08-11     2192.0
# 341   26000000.0   546000000.0  2012-04-18        NaN
# 1503   1800000.0     7650000.0  2018-06-01     2657.0
#
#                                                 address US_state  \
# 85    12TH FLOOR, NO. 1 FINANCIAL STREETCHANG AN CEN...      NaN
# 205   123 ROBERT S. KERR AVENUEOKLAHOMA CITY, OK 731...       OK
# 254   123 ROBERT S. KERR AVENUEOKLAHOMA CITY, OK 731...       OK
# 341   123 ROBERT S. KERR AVENUEOKLAHOMA CITY, OK 731...       OK
# 1503  12TH FLOOR, NO. 1 FINANCIAL STREETCHANG AN CEN...      NaN
#
#                                            descriptions  \
# 85    We are a leading national provider of educatio...
# 205   SandRidge Mississippian Trust I is a Delaware ...
# 254   SandRidge Permian Trust is a Delaware statutor...
# 341   SandRidge Mississippian Trust II is a Delaware...
# 1503  Our mission is to provide Better Schools, Bett...
#
#                                             link_nasdaq       year
# 85    https://www.nasdaq.com/markets/ipos/company/am... 2010-01-01
# 205   https://www.nasdaq.com/markets/ipos/company/sa... 2011-01-01
# 254   https://www.nasdaq.com/markets/ipos/company/sa... 2011-01-01
# 341   https://www.nasdaq.com/markets/ipos/company/sa... 2012-01-01
# 1503  https://www.nasdaq.com/markets/ipos/company/am... 2018-01-01

# %% [markdown]
# Commentary: Ambow Education LTD was enlisted twice. The first one it was liquedated after a scandal in 2014 [1]
# Sandridge Energy Inc - all three are different trusts that belong to one company. Technically they are different.
#
# 1. https://ir.theice.com/press/press-releases/nyse-regulation/2014/nyse-to-immediately-suspend-trading-in-american-depository

# %%
print("number of duplicated tickers in the dataset:", df['Symbol'].duplicated().sum())
# Out:
# number of duplicated tickers in the dataset: 7

# %%
df.iloc[:, :7][df['Symbol'].duplicated(keep=False)]
# Out:
#                                     Company Name Symbol  \
# 60                     HIGHER ONE HOLDINGS, INC.    ONE
# 85                  AMBOW EDUCATION HOLDING LTD.   AMBO
# 97                SEACUBE CONTAINER LEASING LTD.    BOX
# 293                              BAZAARVOICE INC     BV
# 331                            ACQUITY GROUP LTD     AQ
# 356                      TIAA FSB HOLDINGS, INC.   EVER
# 715                     QUOTIENT TECHNOLOGY INC.   COUP
# 948                                      BOX INC    BOX
# 1207                          COUPA SOFTWARE INC   COUP
# 1374                               AQUANTIA CORP     AQ
# 1428  ONESMART INTERNATIONAL EDUCATION GROUP LTD    ONE
# 1477                   BRIGHTVIEW HOLDINGS, INC.     BV
# 1479                             EVERQUOTE, INC.   EVER
# 1503                AMBOW EDUCATION HOLDING LTD.   AMBO
#
#                        Market  Price      Shares  Offer Amount Date Priced
# 60    New York Stock Exchange  12.00   9000000.0   108000000.0  2010-06-17
# 85    New York Stock Exchange  10.00  10677207.0   106772070.0  2010-08-05
# 97    New York Stock Exchange  10.00   9500000.0    95000000.0  2010-10-28
# 293                    NASDAQ  12.00   9484296.0   113811552.0  2012-02-24
# 331   American Stock Exchange   6.00   5555556.0    33333336.0  2012-04-27
# 356   New York Stock Exchange  10.00  19220000.0   192200000.0  2012-05-03
# 715   New York Stock Exchange  16.00  10500000.0   168000000.0  2014-03-07
# 948   New York Stock Exchange  14.00  12500000.0   175000000.0  2015-01-23
# 1207     NASDAQ Global Select  18.00   7400000.0   133200000.0  2016-10-06
# 1374                     NYSE   9.00   6818000.0    61362000.0  2017-11-03
# 1428                     NYSE  11.00  16300000.0   179300000.0  2018-03-28
# 1477                     NYSE  22.00  21300000.0   468600000.0  2018-06-28
# 1479            NASDAQ Global  18.00   4687500.0    84375000.0  2018-06-28
# 1503                 NYSE MKT   4.25   1800000.0     7650000.0  2018-06-01

# %% [markdown]
# Commentary: There are companies that either got defunct and their tickers were given to new IPOs (like EVER) or there are companies that went to IPO twice (like AMBOW). Either way, because I will scrape stock data based on tickers from Yahoo Finance, which has information only for the most recent company, I keep here only those companies that went to IPO later. Others, I declare defunct.

# %%
defunct_oldticker = df['Symbol'][df['Symbol'].duplicated(keep='last')]

# %%
df = df[~df['Symbol'].duplicated(keep='last')]

# %%
df.shape
# Out:
# (1593, 13)

# %% [markdown]
# ## Checking suspicious misalignment between company name and its ticker:

# %% [markdown]
# After scraping IPO companies I noticed that there are some misalignments between company names and their tickers. This could be due to the fact that some companies are now defunct and their tickers belong now to other companies. Or maybe the company is still functional but changed its ticker. Or maybe there was mistake when entering the ticker on Nasdaq website.
#
# So in this step, I check if letters in the symbol correspond to company name. If they don't, I construct a dict of suspect companies. In the next step, I check these suspicious tickers on Yahoo Finance, retrieve their company names  and compare them to company names on Nasdaq list.

# %%
companies_tocheck = {}
for i, symbol in enumerate(df.Symbol):
    for letter in symbol:
        #print(letter)
        if letter not in df.iloc[i, 0]:
            companies_tocheck.update({df.iloc[i, 0]: symbol})

# %%
print(f"{len(companies_tocheck)} companies have suspicious tickers. Will be checked")
# Out:
# 284 companies have suspicious tickers. Will be checked

# %%
url_1 = 'https://finance.yahoo.com/quote/%s/'
url_2 = 'profile?p=%s'
unmatched = {}
unmatched_tickers = []

for i, ticker in enumerate(list(companies_tocheck.values())):
    if i%10 == 0:
        print(f"scraping {ticker} - {i+1}/{len(companies_tocheck)}")
    result = requests.get(url_1 % ticker + url_2 % ticker)
    content = result.content

    soup = BeautifulSoup(content)
    data = soup.find_all("h1", {"class":"D(ib) Fz(16px) Lh(18px)"})
    if data:
        txt = str([x.get_text() for x in data]).replace(ticker, "").lower()
        regex = re.compile("\w+")
        txt = " ".join(regex.findall(txt)).replace("corporation", "corp").replace("limited", "ltd")
        name = df['Company Name'][df['Symbol'] == ticker].values[0].lower().replace(",", "").replace(".", "").replace("corporation", "corp").replace("limited", "ltd")
        #checking with SequenceMatcher if two strings match for at least 80%
        if SequenceMatcher(None, txt, name).ratio() < 0.8:
            unmatched.update({name: txt})
            unmatched_tickers.append(ticker)
# Out:
# scraping CTC - 1/284
# scraping OINK - 11/284
# scraping XNY - 21/284
# scraping QIHU - 31/284
# scraping FENG - 41/284
# scraping RNF - 51/284
# scraping ROYT - 61/284
# scraping SXE - 71/284
# scraping FWM - 81/284
# scraping ONTX - 91/284
# scraping MYCC - 101/284
# scraping CLDN - 111/284
# scraping SQBK - 121/284
# scraping CERU - 131/284
# scraping SGNL - 141/284
# scraping ROKA - 151/284
# scraping JYNT - 161/284
# scraping FLKS - 171/284
# scraping RKDA - 181/284
# scraping MPSX - 191/284
# scraping PAVMU - 201/284
# scraping PTGX - 211/284
# scraping AMMA - 221/284
# scraping GTHX - 231/284
# scraping KIDS - 241/284
# scraping OPBK - 251/284
# scraping ENTX - 261/284
# scraping RUBY - 271/284
# scraping MSC - 281/284

# %%
print(f'there are {len(unmatched_tickers)} unmatched tickers. Will be removed')
unmatched
# Out:
# there are 60 unmatched tickers. Will be removed
# {'ifm investments ltd': '',
#  'energy corp of america': 'eca marcellus trust i',
#  'g-estate liquidation stores inc': 'goldman sachs motif manufacturing revolution etf',
#  'tal education group': 'tal education group american de',
#  'campus crest communities inc': '',
#  'dunxin financial holdings ltd': 'china xiniya fashion ltd am',
#  'assembly biosciences inc': 'virgin trains usa llc',
#  'lentuo international inc': '',
#  'leaf group ltd': 'demand media inc',
#  'emergent capital inc': '',
#  'mmodal inc': 'medx holdings inc',
#  'wright medical group nv': 'taronis technologies inc',
#  'box ships inc': '',
#  'sandridge energy inc': 'sandridge permian trust',
#  'link motion inc': 'mobile inc american deposit',
#  'c&j old coinc': 'c j energy services ltd',
#  'vereit inc': 'american realty capital propert',
#  'aptiv plc': 'delphi technologies plc',
#  'east dubuque nitrogen partners lp': 'rentech nitrogen partners l p',
#  "annie's inc": '',
#  'worldpay inc': 'vantiv inc class a',
#  'erickson inc': 'erickson incorporated',
#  'petrologistics lp': '',
#  'hyperion therapeutics inc': '',
#  'durata therapeutics inc': '',
#  'roan resources inc': 'linn co llc',
#  'fleetmatics group ltd': 'fleetmatics group plc ordinary',
#  'liposcience inc': '',
#  'ready capital corp': 'zais financial corp',
#  'fronteo inc': 'fronteo inc adr each repr 2 ord',
#  'pnmac holdings inc': 'pennymac financial services inc',
#  'telaria inc': 'tremor video inc',
#  'retailmenot inc': 'retailmenot inc series 1',
#  'onemain holdings inc': 'leaf group ltd',
#  'zenith energy logistics partners lp': 'arc logistic partners lp common',
#  'eiger biopharmaceuticals inc': '',
#  'eqt re llc': 'rice energy inc',
#  'chc group ltd': '',
#  'plx pharma inc': 'dipexium pharmaceuticals inc',
#  'function(x) inc': 'see dday',
#  'dare bioscience inc': 'cerulean pharma inc',
#  'miragen therapeutics inc': 'signal genetics inc',
#  'range resources - louisiana inc': 'memorial resource development c',
#  'leap therapeutics inc': 'macrocure ltd ordinary share',
#  'sorrento tech inc': 'sorrento tech inc com usd0 001',
#  'novus therapeutics inc': 'tokai pharmaceuticals inc',
#  'evofem biosciences inc': 'neothetics inc',
#  'syneos health inc': 'syneos health inc com usd0 01 c',
#  'kalvista pharmaceuticals inc': 'carbylan therapeutics inc',
#  'jmu ltd': 'ltd spon adr ea repr ord',
#  'black knight inc': 'black knight financial services',
#  'euronav mi ii inc': 'gener8 maritime inc',
#  'alpine immune sciences inc': 'nivalis therapeutics inc',
#  'sierra oncology inc': 'pronai therapeutics inc',
#  'synlogic inc': 'synlogic inc com usd0 001',
#  'long blockchain corp': 'long island iced tea corp',
#  'innovate biopharmaceuticals inc': 'monster digital inc',
#  'scworx corp': 'alliance mma inc',
#  'cbdmd inc': 'level brands inc',
#  'edison nation inc': 'xspand products lab inc'}

# %%
df = df[~df['Symbol'].isin(unmatched_tickers)]

# %%
df.shape
# Out:
# (1533, 13)

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### 1.1. Scraping stock data

# %%
df_yahoo = pd.DataFrame()
notscraped = []
for i, ticker in enumerate(df.Symbol):
    try:
        if i%10 == 0:
            print(f"scraping {ticker} - {i+1}/{len(df.Symbol)}")
        
        st = pdr.DataReader(ticker, "yahoo")
        st['indx'] = range(len(st))
        inweek_idx = st['indx'][str(df[df['Symbol'] == ticker]['Date Priced'].values[0])] + 7
        inmonth_idx = st['indx'][str(df[df['Symbol'] == ticker]['Date Priced'].values[0])] + 30
        inyear_idx = st['indx'][str(df[df['Symbol'] == ticker]['Date Priced'].values[0])] + 365
        
        firstday_open = st['Open'][str(df[df['Symbol'] == ticker]['Date Priced'].values[0])]
        firstday_adjclose = st['Adj Close'][str(df[df['Symbol'] == ticker]['Date Priced'].values[0])]
        
        inweek_open = st['Open'][st['indx'] == inweek_idx][0]
        inweek_adjclose = st['Adj Close'][st['indx'] == inweek_idx][0]

        inmonth_open = st['Open'][st['indx'] == inmonth_idx][0]
        inmonth_adjclose = st['Adj Close'][st['indx'] == inmonth_idx][0]
        
        inyear_open = st['Open'][st['indx'] == inyear_idx][0]
        inyear_adjclose = st['Adj Close'][st['indx'] == inyear_idx][0]

        
        ticker_df = pd.DataFrame({ticker: {'firstday_adjclose': firstday_adjclose, 'firstday_open': firstday_open, 
                                           'inweek_adjclose': inweek_adjclose, 'inweek_open': inweek_open, 
                                           'inmonth_adjclose': inmonth_adjclose, 'inmonth_open': inmonth_open, 
                                           'inyear_adjclose': inyear_adjclose,'inyear_open': inyear_open}}).T
        df_yahoo = df_yahoo.append(ticker_df)
    except:
        notscraped.append(ticker)
        continue
# Out:
# scraping AMCF - 1/1533
# scraping IRWD - 11/1533
# scraping CRU - 21/1533
# scraping MITL - 31/1533
# scraping TNGN - 41/1533
# scraping CHRM - 51/1533
# scraping BORN - 61/1533
# scraping OXF - 71/1533
# scraping PATH - 81/1533
# scraping GAGA - 91/1533
# scraping TOWR - 101/1533
# scraping ZGNX - 111/1533
# scraping HHC - 121/1533
# scraping QRE - 131/1533
# scraping CTP - 141/1533
# scraping VELT - 151/1533
# scraping GEVO - 161/1533
# scraping CSOD - 171/1533
# scraping ELLI - 181/1533
# scraping TZYM - 191/1533
# scraping FENG - 201/1533
# scraping WIFI - 211/1533
# scraping TAOM - 221/1533
# scraping SKUL - 231/1533
# scraping UBNT - 241/1533
# scraping PACD - 251/1533
# scraping MCEP - 261/1533
# scraping PRLB - 271/1533
# scraping CZR - 281/1533
# scraping MM - 291/1533
# scraping DWRE - 301/1533
# scraping BLOX - 311/1533
# scraping FB - 321/1533
# scraping TSRO - 331/1533
# scraping PANW - 341/1533
# scraping ELOQ - 351/1533
# scraping MEILU - 361/1533
# scraping ANFI - 371/1533
# scraping ATOS - 381/1533
# scraping LAND - 391/1533
# scraping CNOB - 401/1533
# scraping WSTC - 411/1533
# scraping TAM - 421/1533
# scraping IBTX - 431/1533
# scraping DATA - 441/1533
# scraping TSC - 451/1533
# scraping SAMG - 461/1533
# scraping BLUE - 471/1533
# scraping ONTX - 481/1533
# scraping DOC - 491/1533
# scraping MIXT - 501/1533
# scraping CTRL - 511/1533
# scraping MONT - 521/1533
# scraping XLRN - 531/1533
# scraping BRX - 541/1533
# scraping SGM - 551/1533
# scraping BURL - 561/1533
# scraping EVGN - 571/1533
# scraping JGW - 581/1533
# scraping BCRH - 591/1533
# scraping TLOG - 601/1533
# PDM            9.543714          14.75         12.046385     19.299999
#
#       inweek_adjclose  inweek_open  inyear_adjclose  inyear_open
# AMCF         5.830000     6.030000         2.720000         2.58
# GNRC         8.612183    13.050000        13.415763        20.24
# QNST        12.980000    13.500000        12.740000        12.52
# TRNO        14.770803    18.809999        13.518149        17.02
# PDM         10.400203    17.830000        14.289856        21.02

# %% [markdown]
# ## Checking companies not scraped in Yahoo Finance:

# %% [markdown]
# In this part, I will scrutinize the stocks that were nor parsed on Yahoo Finance. There could be two reasons for this - either the company is defunct (merged/was acquired or otherwise delisted from the stock exchange) or the company is still funcational but changed the ticker. In the latter case, we want to include them into our IPO list and redo the scraping from Yahoo Finance for the new ticker. <br>
#
# To check if the company is defunct, I utilize Seeking Alpha website that provides exactly the info we need.

# %%
print(f"From {len(df.Symbol)} IPO companies listed on Nasdaq, {len(notscraped)} companies were not scraped on Yahoo Finance")
# Out:
# From 1533 IPO companies listed on Nasdaq, 699 companies were not scraped on Yahoo Finance

# %%
# defunct = []
# newticker = []
# acquired = []

# url = 'https://seekingalpha.com/symbol/%s'
    
# notscraped_df = pd.DataFrame()
# headers = {'User-Agent' : "non-profit learning project"}

# for ticker in notscraped:
#     print(f'scrap - {url % ticker}')
#     result = requests.get(url % ticker, headers=headers).content
#     sleep(15)
    
#     soup = BeautifulSoup(result)
#     m = soup.find_all("div", {"class": "defunct_message defunct_message_etf"})
#     l = soup.find_all("link", {"rel": "canonical"})
#     if m:
#         print(m)
#         defunct.append(ticker)
#     elif l:
#         print(l)
#         nt = str(l).replace('[<link href="https://seekingalpha.com/symbol/', "").replace('\" rel="canonical"/>]', '')
#         newticker.append(nt)
#     else:
#         acquired.append(ticker)

# %%
# print(f"from {len(df.Symbol)} IPO companies listed on Nasdaq, {len(defunct)} companies are defunct as of May 2019, {len(acquired)} were probably acquired and {len(newticker)} changed their ticker")

# %%
# acquired

# %%
# sorted(defunct)
# df[df['Symbol'].isin(defunct)]

# %%
# newticker[:10]

# %% [markdown]
# ## Joining two dataframes - from NASDAQ and from Yahoo Finance:

# %%
df.index = df.Symbol

# %%
df_ipo = df.join(df_yahoo, how='inner')
df_ipo.head()
# Out:
#                                  Company Name Symbol                   Market  \
# AMCF  ANDATEE CHINA MARINE FUEL SERVICES CORP   AMCF                   NASDAQ
# GNRC                    GENERAC HOLDINGS INC.   GNRC  New York Stock Exchange
# QNST                          QUINSTREET, INC   QNST                   NASDAQ
# TRNO                      TERRENO REALTY CORP   TRNO  New York Stock Exchange
# PDM        PIEDMONT OFFICE REALTY TRUST, INC.    PDM  New York Stock Exchange
#
#       Price      Shares  Offer Amount Date Priced  employees  \
# AMCF    6.3   3134921.0    19750002.0  2010-01-26      128.0
# GNRC   13.0  18750000.0   243750000.0  2010-02-11     1486.0
# QNST   15.0  10000000.0   150000000.0  2010-02-11      568.0
# TRNO   20.0   8750000.0   175000000.0  2010-02-10        6.0
# PDM    14.5  12000000.0   174000000.0  2010-02-10      109.0
#
#                                                 address US_state  ...  \
# AMCF  NO. 68 BINHAI RD DALIAN XIGANG DISTRICTDALIAN ...      NaN  ...
# GNRC            S45 W29290 HIGHWAY 59WAUKESHA, WI 53187       WI  ...
# QNST     950 TOWER LANE, 6TH FLOORFOSTER CITY, CA 94404       CA  ...
# TRNO   16 MAIDEN LANEFIFTH FLOORSAN FRANCISCO, CA 94108       CA  ...
# PDM    5565 GLENRIDGE CONNECTORSTE 450ATLANTA, GA 30342       GA  ...
#
#                                             link_nasdaq       year  \
# AMCF  https://www.nasdaq.com/markets/ipos/company/an... 2010-01-01
# GNRC  https://www.nasdaq.com/markets/ipos/company/ge... 2010-01-01
# QNST  https://www.nasdaq.com/markets/ipos/company/qu... 2010-01-01
# TRNO  https://www.nasdaq.com/markets/ipos/company/te... 2010-01-01
# PDM   https://www.nasdaq.com/markets/ipos/company/pi... 2010-01-01
#
#      firstday_adjclose  firstday_open  inmonth_adjclose  inmonth_open  \
# AMCF          5.770000           6.30          7.590000      8.000000
# GNRC          8.460629          13.00          9.719180     14.910000
# QNST         15.000000          15.00         16.410000     16.010000
# TRNO         14.692022          18.75         15.330121     19.530001
# PDM           9.543714          14.75         12.046385     19.299999
#
#       inweek_adjclose  inweek_open  inyear_adjclose  inyear_open
# AMCF         5.830000     6.030000         2.720000         2.58
# GNRC         8.612183    13.050000        13.415763        20.24
# QNST        12.980000    13.500000        12.740000        12.52
# TRNO        14.770803    18.809999        13.518149        17.02
# PDM         10.400203    17.830000        14.289856        21.02
#
# [5 rows x 21 columns]

# %%
df_ipo.shape
# Out:
# (834, 21)

# %%
df_ipo.to_csv('data/ipo_stock_2010_2018_v2.csv', index=False)

# %% [markdown]
# ## 1.2. Scraping profile and industry from Yahoo Finance

# %% [markdown]
# In this step, I scrape sector, industry, employees as of now, if available CEO pay and CEO year born from Yahoo Finance.

# %%
sector = []
industry = []
employees2019 = []
CEO_pay = []
CEO_born = []

url_1 = 'https://finance.yahoo.com/quote/%s/'
url_2 = 'profile?p=%s'

for i, ticker in enumerate(df_ipo.Symbol):
    print(f"scraping {ticker} - {i+1}/{len(df_ipo.Symbol)}")
    result = requests.get(url_1 % ticker + url_2 % ticker)
    content = result.content

    soup = BeautifulSoup(content)
    data = soup.find_all('span', {"class":"Fw(600)"})
    if data:
        txt = [x.get_text() for x in data]
        sector.append(txt[0])
        industry.append(txt[1])
        employees2019.append(txt[2])

    else:
        sector.append(np.nan)
        industry.append(np.nan)
        employees2019.append(np.nan)
    
    try:
        table = pd.read_html(content)[0]
        #checking if table has CEO 
        if ('Title' in table) and (table['Title'].str.contains('CEO').sum() == 1):
            CEO_pay.append(table['Pay'][table['Title'].str.contains('CEO')].values[0]) 
            CEO_born.append(table['Year Born'][table['Title'].str.contains('CEO')].values[0])
        else:
            CEO_pay.append(np.nan) 
            CEO_born.append(np.nan)

    except ValueError:
        CEO_pay.append(np.nan) 
        CEO_born.append(np.nan)
    
print(f"checking lengths sector: {len(sector)}, industry: {len(industry)}, employees2019: {len(employees2019)}, CEO pay: {len(CEO_pay)}, CEO_born: {len(CEO_born)}")
# Out:
# scraping AMCF - 1/834
# scraping GNRC - 2/834
# scraping QNST - 3/834
# scraping TRNO - 4/834
# scraping PDM - 5/834
# scraping IRWD - 6/834
# scraping SSNC - 7/834
# scraping STNG - 8/834
# scraping HTHT - 9/834
# scraping FIBK - 10/834
# scraping CALX - 11/834
# scraping MXL - 12/834
# scraping AVEO - 13/834
# scraping ST - 14/834
# scraping AOSL - 15/834
# scraping CDXS - 16/834
# scraping ALIM - 17/834
# scraping SPSC - 18/834
# scraping CLDT - 19/834
# scraping PRI - 20/834
# scraping GNMK - 21/834
# scraping JKS - 22/834
# scraping EXPR - 23/834
# scraping RRTS - 24/834
# scraping TNAV - 25/834
# scraping PLOW - 26/834
# scraping TSLA - 27/834
# scraping FN - 28/834
# scraping OAS - 29/834
# scraping GDOT - 30/834
# scraping AMRC - 31/834
# scraping WSR - 32/834
# scraping ELMD - 33/834
# scraping MMYT - 34/834
# scraping RP - 35/834
# scraping NXPI - 36/834
# scraping AMRS - 37/834
# scraping COR - 38/834
# scraping SFUN - 39/834
# scraping PACB - 40/834
# scraping VRA - 41/834
# scraping TOWR - 42/834
# scraping EFC - 43/834
# scraping DQ - 44/834
# scraping STND - 45/834
# scraping CCIH - 46/834
# scraping KEYW - 47/834
# scraping GLBS - 48/834
# scraping ZGNX - 49/834
# scraping GM - 50/834
# scraping LPLA - 51/834
# scraping GNOM - 52/834
# scraping HHC - 53/834
# scraping NOAH - 54/834
# scraping PRMW - 55/834
# scraping CMRE - 56/834
# scraping OSN - 57/834
# scraping WD - 58/834
# scraping RNET - 59/834
# scraping FLT - 60/834
# scraping GCAP - 61/834
# scraping TRGP - 62/834
# scraping AGRO - 63/834
# scraping BKU - 64/834
# scraping INXN - 65/834
# scraping TBET - 66/834
# scraping AAT - 67/834
# scraping ACRX - 68/834
# scraping KMI - 69/834
# scraping FLDM - 70/834
# scraping INN - 71/834
# scraping GEVO - 72/834
# scraping BGMD - 73/834
# scraping NPTN - 74/834
# scraping APO - 75/834
# scraping SREV - 76/834
# scraping CSOD - 77/834
# scraping MX - 78/834
# scraping HCA - 79/834
# scraping VNET - 80/834
# scraping AL - 81/834
# scraping ARCO - 82/834
# scraping TMS - 83/834
# scraping GMLP - 84/834
# scraping UAN - 85/834
# scraping SDT - 86/834
# scraping GNC - 87/834
# scraping APTS - 88/834
# scraping SAVE - 89/834
# scraping YNDX - 90/834
# scraping KOS - 91/834
# scraping RENN - 92/834
# scraping WIFI - 93/834
# scraping MITT - 94/834
# scraping CHEF - 95/834
# scraping WAIR - 96/834
# scraping HZNP - 97/834
# scraping AMID - 98/834
# scraping DNKN - 99/834
# scraping FRAN - 100/834
# scraping SXC - 101/834
# scraping CARB - 102/834
# scraping UBNT - 103/834
# scraping IMI - 104/834
# scraping MN - 105/834
# scraping ANGI - 106/834
# scraping CHKR - 107/834
# scraping NLNK - 108/834
# scraping PACD - 109/834
# scraping GRPN - 110/834
# scraping ZNGA - 111/834
# scraping BCEI - 112/834
# scraping LPI - 113/834
# scraping MCEP - 114/834
# scraping VSTM - 115/834
# scraping GWRE - 116/834
# scraping REGI - 117/834
# scraping PRLB - 118/834
# scraping BCOV - 119/834
# scraping HMST - 120/834
# scraping CCXI - 121/834
# scraping CZR - 122/834
# scraping EPAM - 123/834
# scraping MTDR - 124/834
# scraping SLCA - 125/834
# scraping ENPH - 126/834
# scraping GLOG - 127/834
# scraping MACK - 128/834
# scraping RXN - 129/834
# scraping RM - 130/834
# scraping VCRA - 131/834
# scraping VIPS - 132/834
# scraping CSTE - 133/834
# scraping ET - 134/834
# scraping ALSN - 135/834
# scraping MTSI - 136/834
# scraping YELP - 137/834
# scraping ARCT - 138/834
# scraping CLIR - 139/834
# scraping MPO - 140/834
# scraping PFPT - 141/834
# scraping SPLK - 142/834
# scraping SDR - 143/834
# scraping MRC - 144/834
# scraping FET - 145/834
# scraping FB - 146/834
# scraping TLYS - 147/834
# scraping ROYT - 148/834
# scraping SUPN - 149/834
# scraping NOW - 150/834
# scraping EQM - 151/834
# scraping DFRG - 152/834
# scraping NGVC - 153/834
# scraping CHUY - 154/834
# scraping PANW - 155/834
# scraping FSBW - 156/834
# scraping HCLP - 157/834
# scraping MANU - 158/834
# scraping PFMT - 159/834
# scraping BLMN - 160/834
# scraping GMED - 161/834
# scraping QLYS - 162/834
# scraping SMLP - 163/834
# scraping NBHC - 164/834
# scraping SRC - 165/834
# scraping MPLX - 166/834
# scraping SDLP - 167/834
# scraping WDAY - 168/834
# scraping FANG - 169/834
# scraping ICPT - 170/834
# scraping SSTK - 171/834
# scraping RLGY - 172/834
# scraping AMBA - 173/834
# scraping BERY - 174/834
# scraping YY - 175/834
# scraping WHLR - 176/834
# scraping ATOS - 177/834
# scraping DKL - 178/834
# scraping RH - 179/834
# scraping PBF - 180/834
# scraping TPH - 181/834
# scraping STML - 182/834
# scraping BFAM - 183/834
# scraping NCLH - 184/834
# scraping CONE - 185/834
# scraping SXCP - 186/834
# scraping USAC - 187/834
# scraping AFH - 188/834
# scraping CNOB - 189/834
# scraping HIIQ - 190/834
# scraping XONE - 191/834
# scraping BCC - 192/834
# scraping ZTS - 193/834
# scraping MRIN - 194/834
# scraping ENTA - 195/834
# scraping MODN - 196/834
# scraping TTPH - 197/834
# scraping APAM - 198/834
# scraping SEAS - 199/834
# scraping I - 200/834
# scraping HASI - 201/834
# scraping EVTC - 202/834
# scraping CMRX - 203/834
# scraping TMHC - 204/834
# scraping EPZM - 205/834
# scraping KMDA - 206/834
# scraping ECOM - 207/834
# scraping BRSS - 208/834
# scraping CSTM - 209/834
# scraping PTLA - 210/834
# scraping DATA - 211/834
# scraping EMES - 212/834
# scraping TSC - 213/834
# scraping AHH - 214/834
# scraping QIWI - 215/834
# scraping GWPH - 216/834
# scraping EARN - 217/834
# scraping NDLS - 218/834
# scraping PETX - 219/834
# scraping CDW - 220/834
# scraping HDS - 221/834
# scraping ESPR - 222/834
# scraping NSTG - 223/834
# scraping LXFT - 224/834
# scraping GOGO - 225/834
# scraping PTCT - 226/834
# scraping BLUE - 227/834
# scraping BEP - 228/834
# scraping LITB - 229/834
# scraping ONTX - 230/834
# scraping CNAT - 231/834
# scraping AGIO - 232/834
# scraping GRAM - 233/834
# scraping HTBX - 234/834
# scraping PSXP - 235/834
# scraping REXR - 236/834
# scraping DOC - 237/834
# scraping OMED - 238/834
# scraping SPHS - 239/834
# scraping IRT - 240/834
# scraping MIXT - 241/834
# scraping FI - 242/834
# scraping XON - 243/834
# scraping FOXF - 244/834
# scraping CTRL - 245/834
# scraping MBII - 246/834
# scraping AMH - 247/834
# scraping ASC - 248/834
# scraping PEGI - 249/834
# scraping RNG - 250/834
# scraping PINC - 251/834
# scraping AAOI - 252/834
# scraping EVOK - 253/834
# scraping FEYE - 254/834
# scraping XLRN - 255/834
# scraping FPRX - 256/834
# scraping BNFT - 257/834
# scraping VLRS - 258/834
# scraping ESNT - 259/834
# scraping MMI - 260/834
# scraping WUBA - 261/834
# scraping BRX - 262/834
# scraping CRTO - 263/834
# scraping COMM - 264/834
# scraping SRLP - 265/834
# scraping EIGI - 266/834
# scraping AERI - 267/834
# scraping VJET - 268/834
# scraping VEEV - 269/834
# scraping PAGP - 270/834
# scraping MGNX - 271/834
# scraping AR - 272/834
# scraping QTS - 273/834
# scraping PBPB - 274/834
# scraping CHMI - 275/834
# scraping BURL - 276/834
# scraping ESRT - 277/834
# scraping RMAX - 278/834
# scraping FATE - 279/834
# scraping IPWR - 280/834
# scraping VNCE - 281/834
# scraping WBAI - 282/834
# scraping NVGS - 283/834
# scraping EVGN - 284/834
# scraping TNDM - 285/834
# scraping HMHC - 286/834
# scraping EROS - 287/834
# scraping DLNG - 288/834
# scraping CHGG - 289/834
# scraping STAY - 290/834
# scraping NMIH - 291/834
# scraping LGIH - 292/834
# scraping TWTR - 293/834
# scraping WIX - 294/834
# scraping KPTI - 295/834
# scraping AVH - 296/834
# scraping BCRH - 297/834
# scraping TCS - 298/834
# scraping AMC - 299/834
# scraping HLT - 300/834
# scraping KIN - 301/834
# scraping SALT - 302/834
# scraping TLOG - 303/834
# scraping CTT - 304/834
# scraping ARMK - 305/834
# scraping ATHM - 306/834
# scraping XNCR - 307/834
# scraping CARA - 308/834
# scraping NWHM - 309/834
# scraping RARE - 310/834
# scraping MBUU - 311/834
# scraping TRVN - 312/834
# scraping DRNA - 313/834
# scraping CRCM - 314/834
# scraping AKER - 315/834
# scraping SC - 316/834
# scraping EPE - 317/834
# scraping CELP - 318/834
# scraping GLYC - 319/834
# scraping RTRX - 320/834
# scraping SMLR - 321/834
# scraping INGN - 322/834
# scraping IBP - 323/834
# scraping CNCE - 324/834
# scraping EGRX - 325/834
# scraping FLXN - 326/834
# scraping GPRK - 327/834
# scraping LADR - 328/834
# scraping RVNC - 329/834
# scraping QURE - 330/834
# scraping GNCA - 331/834
# scraping CBPX - 332/834
# scraping BIOC - 333/834
# scraping BRG - 334/834
# scraping HIVE - 335/834
# scraping TWOU - 336/834
# scraping WATT - 337/834
# scraping TNET - 338/834
# scraping AGTC - 339/834
# scraping AMBR - 340/834
# scraping ATEN - 341/834
# scraping QTWO - 342/834
# scraping AKBA - 343/834
# scraping MDWD - 344/834
# scraping PCTY - 345/834
# scraping CSLT - 346/834
# scraping GLMD - 347/834
# scraping AKAO - 348/834
# scraping AQXP - 349/834
# scraping REPH - 350/834
# scraping SABR - 351/834
# scraping SPWH - 352/834
# scraping LEJU - 353/834
# scraping MC - 354/834
# scraping PAYC - 355/834
# scraping CIO - 356/834
# scraping PAHC - 357/834
# scraping FPI - 358/834
# scraping ENBL - 359/834
# scraping ADMS - 360/834
# scraping ALLY - 361/834
# scraping GRUB - 362/834
# scraping FIVN - 363/834
# scraping RUBI - 364/834
# scraping PIH - 365/834
# scraping RESN - 366/834
# scraping PE - 367/834
# scraping AGRX - 368/834
# scraping HRTG - 369/834
# scraping SDPI - 370/834
# scraping JD - 371/834
# scraping TGEN - 372/834
# scraping TRUE - 373/834
# scraping JMEI - 374/834
# scraping BWFG - 375/834
# scraping ZEN - 376/834
# scraping SFBS - 377/834
# scraping TOUR - 378/834
# scraping PBFX - 379/834
# scraping CMCM - 380/834
# scraping LPG - 381/834
# scraping ALDR - 382/834
# scraping GLOP - 383/834
# scraping SCYX - 384/834
# scraping FRSH - 385/834
# scraping ARES - 386/834
# scraping MIK - 387/834
# scraping NEP - 388/834
# scraping SERV - 389/834
# scraping GPRO - 390/834
# scraping AMPH - 391/834
# scraping MTLS - 392/834
# scraping XNET - 393/834
# scraping ARDX - 394/834
# scraping VNOM - 395/834
# scraping FELP - 396/834
# scraping CCS - 397/834
# scraping ASPN - 398/834
# scraping MOBL - 399/834
# scraping TSE - 400/834
# scraping NAO - 401/834
# scraping RDUS - 402/834
# scraping ANET - 403/834
# scraping CTLT - 404/834
# scraping HQY - 405/834
# scraping MRNS - 406/834
# scraping SYF - 407/834
# scraping LOCO - 408/834
# scraping OCUL - 409/834
# scraping OEC - 410/834
# scraping WMS - 411/834
# scraping XENT - 412/834
# scraping TSQ - 413/834
# scraping PFNX - 414/834
# scraping MTBC - 415/834
# scraping GLOB - 416/834
# scraping TERP - 417/834
# scraping TRUP - 418/834
# scraping CDNA - 419/834
# scraping IRMD - 420/834
# scraping ISTR - 421/834
# scraping NERV - 422/834
# scraping OTIC - 423/834
# scraping RYI - 424/834
# scraping ICD - 425/834
# scraping HMLP - 426/834
# scraping TTOO - 427/834
# scraping EARS - 428/834
# scraping GWGH - 429/834
# scraping TVPT - 430/834
# scraping MDLY - 431/834
# scraping SFS - 432/834
# scraping ICL - 433/834
# scraping CYBR - 434/834
# scraping CFG - 435/834
# scraping AVAL - 436/834
# scraping BABA - 437/834
# scraping FOMX - 438/834
# scraping PRQR - 439/834
# scraping RWLK - 440/834
# scraping AFMD - 441/834
# scraping BOOT - 442/834
# scraping FSAM - 443/834
# scraping SHLX - 444/834
# scraping SIEN - 445/834
# scraping DBVT - 446/834
# scraping PRTO - 447/834
# scraping ZAYO - 448/834
# scraping ATRA - 449/834
# scraping GWB - 450/834
# scraping PLAY - 451/834
# scraping DPLO - 452/834
# scraping HUBS - 453/834
# scraping USDP - 454/834
# scraping VBTX - 455/834
# scraping DERM - 456/834
# scraping ATTO - 457/834
# scraping CALA - 458/834
# scraping W - 459/834
# scraping VSLR - 460/834
# scraping VBLT - 461/834
# scraping SKIS - 462/834
# scraping HABT - 463/834
# scraping EYES - 464/834
# scraping PGRE - 465/834
# scraping STOR - 466/834
# scraping FGEN - 467/834
# scraping PRAH - 468/834
# scraping SKYS - 469/834
# scraping AXTA - 470/834
# scraping JYNT - 471/834
# scraping FRPT - 472/834
# scraping TBK - 473/834
# scraping UPLD - 474/834
# scraping CHRS - 475/834
# scraping NVRO - 476/834
# scraping AM - 477/834
# scraping XENE - 478/834
# scraping BLCM - 479/834
# scraping ONDK - 480/834
# scraping WK - 481/834
# scraping NEWR - 482/834
# scraping FCAU - 483/834
# scraping JRVR - 484/834
# scraping LC - 485/834
# scraping MOMO - 486/834
# scraping AVGR - 487/834
# scraping HIFR - 488/834
# scraping ONCE - 489/834
# scraping SHAK - 490/834
# scraping TCON - 491/834
# scraping LENS - 492/834
# scraping FLKS - 493/834
# scraping ASND - 494/834
# scraping ZSAN - 495/834
# scraping BOX - 496/834
# scraping ICBK - 497/834
# scraping AJX - 498/834
# scraping BLPH - 499/834
# scraping NVTA - 500/834
# scraping INOV - 501/834
# scraping DEA - 502/834
# scraping JCAP - 503/834
# scraping FSB - 504/834
# scraping SEDG - 505/834
# scraping CLLS - 506/834
# scraping TANH - 507/834
# scraping SUM - 508/834
# scraping SMMT - 509/834
# scraping BPMC - 510/834
# scraping EVA - 511/834
# scraping VKTX - 512/834
# scraping NSA - 513/834
# scraping PRTY - 514/834
# scraping VIRT - 515/834
# scraping KMPH - 516/834
# scraping ETSY - 517/834
# scraping XBIT - 518/834
# scraping CDTX - 519/834
# scraping ADRO - 520/834
# scraping KRNT - 521/834
# scraping GDDY - 522/834
# scraping BZUN - 523/834
# scraping CHCT - 524/834
# scraping SHOP - 525/834
# scraping FTAI - 526/834
# scraping RKDA - 527/834
# scraping GLPG - 528/834
# scraping JAGX - 529/834
# scraping BVXV - 530/834
# scraping COLL - 531/834
# scraping LIFE - 532/834
# scraping HTGM - 533/834
# scraping ADAP - 534/834
# scraping OPGN - 535/834
# scraping BSM - 536/834
# scraping ALRM - 537/834
# scraping APPF - 538/834
# scraping GPP - 539/834
# scraping MCRB - 540/834
# scraping TRU - 541/834
# scraping MCRN - 542/834
# scraping LNTH - 543/834
# scraping GKOS - 544/834
# scraping CATB - 545/834
# scraping RTTR - 546/834
# scraping CYAD - 547/834
# scraping FIT - 548/834
# scraping UNVR - 549/834
# scraping WING - 550/834
# scraping PUB - 551/834
# scraping DTEA - 552/834
# scraping AQMS - 553/834
# scraping NK - 554/834
# scraping NEOS - 555/834
# scraping MCFT - 556/834
# scraping RPD - 557/834
# scraping OLLI - 558/834
# scraping JP - 559/834
# scraping CHMA - 560/834
# scraping HLG - 561/834
# scraping NTRA - 562/834
# scraping CFMS - 563/834
# scraping TDOC - 564/834
# scraping BNTC - 565/834
# scraping HLI - 566/834
# scraping GBT - 567/834
# scraping AIMT - 568/834
# scraping PLNT - 569/834
# scraping RUN - 570/834
# scraping ZYNE - 571/834
# scraping NTEC - 572/834
# scraping NBRV - 573/834
# scraping PEN - 574/834
# scraping RGNX - 575/834
# scraping MYOK - 576/834
# scraping IOTS - 577/834
# scraping RACE - 578/834
# scraping FDC - 579/834
# scraping PMTS - 580/834
# scraping CTMX - 581/834
# scraping ABTX - 582/834
# scraping ACRS - 583/834
# scraping PSTG - 584/834
# scraping NVCR - 585/834
# scraping SGRY - 586/834
# scraping DLTH - 587/834
# scraping AXSM - 588/834
# scraping MIME - 589/834
# scraping MTCH - 590/834
# scraping SQ - 591/834
# scraping MESO - 592/834
# scraping INST - 593/834
# scraping VYGR - 594/834
# scraping WVE - 595/834
# scraping EQBK - 596/834
# scraping KURA - 597/834
# scraping FORK - 598/834
# scraping CCRC - 599/834
# scraping YRD - 600/834
# scraping TEAM - 601/834
# scraping PTI - 602/834
# scraping BGNE - 603/834
# scraping EDIT - 604/834
# scraping CRVS - 605/834
# scraping SENS - 606/834
# scraping HCM - 607/834
# scraping SNDX - 608/834
# scraping GWRS - 609/834
# scraping YIN - 610/834
# scraping SCWX - 611/834
# scraping ARA - 612/834
# scraping MGP - 613/834
# scraping AGLE - 614/834
# scraping GMS - 615/834
# scraping RETA - 616/834
# scraping USFD - 617/834
# scraping MSBI - 618/834
# scraping MRUS - 619/834
# scraping SUPV - 620/834
# scraping PLSE - 621/834
# scraping ACIA - 622/834
# scraping SITE - 623/834
# scraping TPB - 624/834
# scraping SBPH - 625/834
# scraping NTLA - 626/834
# scraping SYRS - 627/834
# scraping TWLO - 628/834
# scraping SELB - 629/834
# scraping COE - 630/834
# scraping ATKR - 631/834
# scraping CLSD - 632/834
# scraping MBRX - 633/834
# scraping NH - 634/834
# scraping TLND - 635/834
# scraping TCMD - 636/834
# scraping KNSL - 637/834
# scraping KDMN - 638/834
# scraping TPIC - 639/834
# scraping PI - 640/834
# scraping BOLD - 641/834
# scraping LN - 642/834
# scraping AIRG - 643/834
# scraping MEDP - 644/834
# scraping PTGX - 645/834
# scraping GEMP - 646/834
# scraping FHB - 647/834
# scraping NTNX - 648/834
# scraping TRHC - 649/834
# scraping MRT - 650/834
# scraping FLGT - 651/834
# scraping TYHT - 652/834
# scraping VVV - 653/834
# scraping GSUM - 654/834
# scraping ACIU - 655/834
# scraping CSTR - 656/834
# scraping ELF - 657/834
# scraping NOVN - 658/834
# scraping TTD - 659/834
# scraping EVBG - 660/834
# scraping FBK - 661/834
# scraping NTB - 662/834
# scraping NBLX - 663/834
# scraping BL - 664/834
# scraping GOLF - 665/834
# scraping QTNA - 666/834
# scraping ZTO - 667/834
# scraping MYOV - 668/834
# scraping RARX - 669/834
# scraping FRTA - 670/834
# scraping IRTC - 671/834
# scraping TUSK - 672/834
# scraping XOG - 673/834
# scraping AZRE - 674/834
# scraping AZRX - 675/834
# scraping CWH - 676/834
# scraping MRAM - 677/834
# scraping ADSW - 678/834
# scraping OBLN - 679/834
# scraping COUP - 680/834
# scraping WAAS - 681/834
# scraping MTFB - 682/834
# scraping SND - 683/834
# scraping GDS - 684/834
# scraping HEBT - 685/834
# scraping TRVG - 686/834
# scraping ICHR - 687/834
# scraping SNES - 688/834
# scraping POLA - 689/834
# scraping IIPR - 690/834
# scraping JAG - 691/834
# scraping JELD - 692/834
# scraping JNCE - 693/834
# scraping REVG - 694/834
# scraping OBSV - 695/834
# scraping ANAB - 696/834
# scraping FRAC - 697/834
# scraping CLPR - 698/834
# scraping FBM - 699/834
# scraping SACH - 700/834
# scraping KRP - 701/834
# scraping INVH - 702/834
# scraping AYX - 703/834
# scraping VLRX - 704/834
# scraping PUMP - 705/834
# scraping ARD - 706/834
# scraping PSDO - 707/834
# scraping JILL - 708/834
# scraping BYSI - 709/834
# scraping SNAP - 710/834
# scraping HLNE - 711/834
# scraping CLDR - 712/834
# scraping CVNA - 713/834
# scraping EEX - 714/834
# scraping NCSM - 715/834
# scraping XRF - 716/834
# scraping ZYME - 717/834
# scraping VRNA - 718/834
# scraping CATS - 719/834
# scraping TOCA - 720/834
# scraping CADE - 721/834
# scraping HCC - 722/834
# scraping YEXT - 723/834
# scraping NETS - 724/834
# scraping OKTA - 725/834
# scraping SNDR - 726/834
# scraping ELVT - 727/834
# scraping HESM - 728/834
# scraping APPN - 729/834
# scraping WOW - 730/834
# scraping SGH - 731/834
# scraping ARGX - 732/834
# scraping BEDU - 733/834
# scraping GTHX - 734/834
# scraping SOI - 735/834
# scraping ASV - 736/834
# scraping GDI - 737/834
# scraping VERI - 738/834
# scraping GNTY - 739/834
# scraping OVID - 740/834
# scraping URGN - 741/834
# scraping BHVN - 742/834
# scraping BY - 743/834
# scraping APRN - 744/834
# scraping DOVA - 745/834
# scraping MRSN - 746/834
# scraping ATXI - 747/834
# scraping GPMT - 748/834
# scraping SAFE - 749/834
# scraping SGBX - 750/834
# scraping ATUS - 751/834
# scraping ADOM - 752/834
# scraping ATNX - 753/834
# scraping IMRN - 754/834
# scraping SSTI - 755/834
# scraping NEWA - 756/834
# scraping RDFN - 757/834
# scraping SNNA - 758/834
# scraping RBB - 759/834
# scraping PETQ - 760/834
# scraping KALA - 761/834
# scraping CLXT - 762/834
# scraping AKCA - 763/834
# scraping CODX - 764/834
# scraping CSSE - 765/834
# scraping RNGR - 766/834
# scraping YOGA - 767/834
# scraping ZEAL - 768/834
# scraping CIFS - 769/834
# scraping VNTR - 770/834
# scraping ROKU - 771/834
# scraping DCPH - 772/834
# scraping NCNA - 773/834
# scraping NITE - 774/834
# scraping RYB - 775/834
# scraping SECO - 776/834
# scraping OMP - 777/834
# scraping PETZ - 778/834
# scraping DESP - 779/834
# scraping CELC - 780/834
# scraping KRYS - 781/834
# scraping ZLAB - 782/834
# scraping TRMT - 783/834
# scraping ZKIN - 784/834
# scraping FSCT - 785/834
# scraping NEXA - 786/834
# scraping EYE - 787/834
# scraping BPMP - 788/834
# scraping FAT - 789/834
# scraping REDU - 790/834
# scraping RMBL - 791/834
# scraping MDB - 792/834
# scraping QD - 793/834
# scraping OPTN - 794/834
# scraping KIDS - 795/834
# scraping HAIR - 796/834
# scraping CARG - 797/834
# scraping SWCH - 798/834
# scraping RYTM - 799/834
# scraping BOXL - 800/834
# scraping RETO - 801/834
# scraping BXG - 802/834
# scraping AMRH - 803/834
# scraping SBT - 804/834
# scraping SCPH - 805/834
# scraping SFIX - 806/834
# scraping JT - 807/834
# scraping PPDF - 808/834
# scraping ERYP - 809/834
# scraping APLS - 810/834
# scraping SOGO - 811/834
# scraping MCB - 812/834
# scraping FEDU - 813/834
# scraping IFRX - 814/834
# scraping CBTX - 815/834
# scraping HX - 816/834
# scraping AQ - 817/834
# scraping ACMR - 818/834
# scraping SPRO - 819/834
# scraping ALNA - 820/834
# scraping AQUA - 821/834
# scraping ALTR - 822/834
# scraping LOMA - 823/834
# scraping ICLK - 824/834
# scraping LX - 825/834
# scraping DOGZ - 826/834
# scraping CASA - 827/834
# scraping NMRK - 828/834
# scraping DNLI - 829/834
# scraping LBC - 830/834
# scraping CURO - 831/834
# scraping ODT - 832/834
# scraping QTRX - 833/834
# scraping CUE - 834/834
# checking lengths sector: 834, industry: 834, employees2019: 834, CEO pay: 834, CEO_born: 834

# %%
employees2019_clean = []
for emp in employees2019:
    if emp is not np.nan:
        if len(emp) > 0:
            emp = int(emp.replace(',', ''))
        else:
            emp = np.nan
    employees2019_clean.append(emp)

# %%
CEO_pay_clean = []
for i, cp in enumerate(CEO_pay):
    if cp == cp:
        if isinstance(cp, float):
            print(i, cp)
            cp_clean = cp*1000
        elif 'M' in cp:
            print(i, cp)
            cp_clean = float(cp.replace("M", ""))*1000000
        elif 'k' in cp:
            print(i, cp)
            cp_clean = float(cp.replace("k", ""))*1000        
        CEO_pay_clean.append(cp_clean)
    elif cp != cp:
        print(i, 'this one', cp)
        CEO_pay_clean.append(cp)
# Out:
# 0 this one nan
# 1 2.52M
# 2 816.15k
# 3 799.5k
# 4 this one nan
# 5 this one nan
# 6 10.88M
# 7 this one nan
# 8 this one nan
# 9 1.71M
# 10 500k
# 11 554.71k
# 12 770.17k
# 13 1.57M
# 14 1.34M
# 15 1.15M
# 16 501.12k
# 17 1.39M
# 18 2.39M
# 19 2.39M
# 20 1M
# 21 this one nan
# 22 this one nan
# 23 839.92k
# 24 821.3k
# 25 854.23k
# 26 56.38k
# 27 700.01k
# 28 1.84M
# 29 1.88M
# 30 1.17M
# 31 619.25k
# 32 418.35k
# 33 this one nan
# 34 1.38M
# 35 4.45M
# 36 1.8M
# 37 1.52M
# 38 this one nan
# 39 1.03M
# 40 1.4M
# 41 2.11M
# 42 this one nan
# 43 this one nan
# 44 this one nan
# 45 this one nan
# 46 978.89k
# 47 this one nan
# 48 869.7k
# 49 7.36M
# 50 3.26M
# 51 this one nan
# 52 6.01M
# 53 this one nan
# 54 461.26k
# 55 this one nan
# 56 13.69k
# 57 2.25M
# 58 1.47M
# 59 2.53M
# 60 2.22M
# 61 856.64k
# 62 this one nan
# 63 3.1M
# 64 this one nan
# 65 this one nan
# 66 1.82M
# 67 941k
# 68 908.96k
# 69 1.05M
# 70 1.68M
# 71 790.22k
# 72 429.17k
# 73 638.34k
# 74 252.62k
# 75 375.72k
# 76 1.67M
# 77 1.15M
# 78 3.84M
# 79 this one nan
# 80 3.52M
# 81 this one nan
# 82 this one nan
# 83 this one nan
# 84 1.66M
# 85 this one nan
# 86 4.4M
# 87 1M
# 88 1.55M
# 89 this one nan
# 90 2.75M
# 91 this one nan
# 92 65.5k
# 93 this one nan
# 94 1.54M
# 95 1.21M
# 96 3.26M
# 97 this one nan
# 98 1.35M
# 99 this one nan
# 100 1.67M
# 101 867.8k
# 102 this one nan
# 103 892.5k
# 104 this one nan
# 816 648k
# 817 342.18k
# 818 721.32k
# 819 619.22k
# 820 935.45k
# 821 1.42M
# 822 this one nan
# 823 this one nan
# 824 this one nan
# 825 14.81k
# 826 1.66M
# 827 this one nan
# 828 1.07M
# 829 this one nan
# 830 827.04k
# 832 1.11M
# 833 452.69k

# %% [markdown]
# # Final DataFrame

# %%
df_ipo['sector'] = sector
df_ipo['industry'] = industry
df_ipo['employees2019'] = employees2019_clean
df_ipo['CEO_pay'] = CEO_pay_clean
df_ipo['CEO_born'] = CEO_born

# %%
df_ipo.head()
# Out:
#                                  Company Name Symbol                   Market  \
# AMCF  ANDATEE CHINA MARINE FUEL SERVICES CORP   AMCF                   NASDAQ
# GNRC                    GENERAC HOLDINGS INC.   GNRC  New York Stock Exchange
# QNST                          QUINSTREET, INC   QNST                   NASDAQ
# TRNO                      TERRENO REALTY CORP   TRNO  New York Stock Exchange
# PDM        PIEDMONT OFFICE REALTY TRUST, INC.    PDM  New York Stock Exchange
#
#       Price      Shares  Offer Amount Date Priced  employees  \
# AMCF    6.3   3134921.0    19750002.0  2010-01-26      128.0
# GNRC   13.0  18750000.0   243750000.0  2010-02-11     1486.0
# QNST   15.0  10000000.0   150000000.0  2010-02-11      568.0
# TRNO   20.0   8750000.0   175000000.0  2010-02-10        6.0
# PDM    14.5  12000000.0   174000000.0  2010-02-10      109.0
#
#                                                 address US_state  ...  \
# AMCF  NO. 68 BINHAI RD DALIAN XIGANG DISTRICTDALIAN ...      NaN  ...
# GNRC            S45 W29290 HIGHWAY 59WAUKESHA, WI 53187       WI  ...
# QNST     950 TOWER LANE, 6TH FLOORFOSTER CITY, CA 94404       CA  ...
# TRNO   16 MAIDEN LANEFIFTH FLOORSAN FRANCISCO, CA 94108       CA  ...
# PDM    5565 GLENRIDGE CONNECTORSTE 450ATLANTA, GA 30342       GA  ...
#
#      inmonth_open inweek_adjclose inweek_open  inyear_adjclose  inyear_open  \
# AMCF     8.000000        5.830000    6.030000         2.720000         2.58
# GNRC    14.910000        8.612183   13.050000        13.415763        20.24
# QNST    16.010000       12.980000   13.500000        12.740000        12.52
# TRNO    19.530001       14.770803   18.809999        13.518149        17.02
# PDM     19.299999       10.400203   17.830000        14.289856        21.02
#
#            sector                        industry  employees2019    CEO_pay  \
# AMCF       Energy  Oil & Gas Equipment & Services          189.0        NaN
# GNRC  Industrials         Diversified Industrials         5046.0  2520000.0
# QNST   Technology  Internet Content & Information          506.0   816150.0
# TRNO  Real Estate               REIT - Industrial           23.0   799500.0
# PDM   Real Estate                   REIT - Office          134.0        NaN
#
#       CEO_born
# AMCF       NaN
# GNRC    1972.0
# QNST    1960.0
# TRNO    1961.0
# PDM        NaN
#
# [5 rows x 26 columns]

# %%
df_ipo.shape
# Out:
# (834, 26)

# %%
df_ipo.to_csv('data/ipo_stock_2010_2018_v2.csv', index=False)

# %% [markdown]
# ## Creating dill to serialize python objects

# %%
import sys
print(sys.getrecursionlimit())
sys.setrecursionlimit(10000)
print(sys.getrecursionlimit())
# Out:
# 3000
# 10000

# %%
dill.dump_session('dill/ipo_price_scraper.pkl')
